# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict

from matrixprofile import *

# %%
X_train_decimated_scaled_max = np.load("RavdessAudioOnlyNumpy__X_train_decimated_scaled_max.npy")
X_test_decimated_scaled_max = np.load("RavdessAudioOnlyNumpy__X_test_decimated_scaled_max.npy")
X_decimated_scaled_max = np.load("RavdessAudioOnlyNumpy__X_decimated_scaled_max.npy")
df_decimated_scaled_max=pd.DataFrame(X_decimated_scaled_max)

# %%
centroid1=np.load("kmeans_dtw_1st_centroid.npy")

# %%
centroid1
# Out:
# array([ 2.20707572, -0.18078738, -0.93119387, -2.51021618, -0.04146413,
#         1.85153338,  3.61300189,  2.00251965,  1.29528759,  1.33745274,
#         0.80467766, -0.80878959,  0.49711605,  0.61007185,  0.61368878,
#         1.46922527,  0.68866608,  0.50497718, -0.58296573, -1.82467241,
#        -3.45714974, -6.0901704 , -3.50808488,  1.20900862,  5.22391094,
#         7.63486521,  3.41935299, -0.83698784, -4.22771384, -1.96939557,
#        -0.01201241,  2.03491241,  3.04131116,  2.97288951,  2.99534879,
#         4.40684173,  2.70047455,  0.83674188, -1.93108686,  0.22692088,
#         1.23577563,  1.29289023,  2.92786705,  1.27599415,  0.82372263,
#         1.09777607,  0.98960288, -0.38519615, -2.60042051, -0.13452631])

# %%
centroid1.shape
# Out:
# (50,)

# %%
centroid2=np.load("kmeans_dtw_2nd_centroid.npy")

# %% [markdown]
# ## Motifs centroid 1

# %%
for w in range(3,11):
    mp1, mpi1 = matrixProfile.stomp(centroid1, w)
    plt.figure(figsize=(10,10))
    plt.plot(mp1)
    plt.ylabel("MatrixProfile value", fontsize=15)
    plt.text(0.95, 0.95, "Window size = "+str(w), fontsize=15, bbox=dict(facecolor="red", alpha=0.5), transform=plt.gca().transAxes, verticalalignment='top', horizontalalignment='right')
    plt.show()

# %%
w=7
mp1, mpi1 = matrixProfile.stomp(centroid1, w)
mo1, mod1  = motifs.motifs(centroid1, (mp1, mpi1), max_motifs=5)
print(mo1)
# Out:
# [[11, 38], [0, 18, 26], [33, 43]]

# %%
for w in range(3,11):
    mp1, mpi1 = matrixProfile.stomp(centroid1, w)
    plt.figure(figsize=(10,10))
    plt.plot(mp1)
    plt.ylabel("MatrixProfile value", fontsize=15)
    plt.text(0.95, 0.95, "Window size = "+str(w), fontsize=15, bbox=dict(facecolor="red", alpha=0.5), transform=plt.gca().transAxes, verticalalignment='top', horizontalalignment='right')
    plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(np.arange(1,len(centroid1)+1),centroid1)
colors = ['r', 'g', 'k', 'b', 'y'][:len(mo1)]
for m, d, c in zip(mo1, mod1, colors):
    if c=="r":
        for i in m:
            if i==mo1[0][0]:
                m_shape = centroid1[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5, label="First Motif")
            else:
                m_shape = centroid1[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5)                
    elif c=="g":
        for i in m:
            if i==mo1[1][0]:
                m_shape = centroid1[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5, label="Second Motif")
            else:
                m_shape = centroid1[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5) 
    elif c=="k":
        for i in m:
            if i==mo1[2][0]:
                m_shape = centroid1[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5, label="Third Motif")
            else:
                m_shape = centroid1[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5)
    elif c=="b":
        for i in m:
            if i==mo1[3][0]:
                m_shape = centroid1[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5, label="Fourth Motif")
            else:
                m_shape = centroid1[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5)
    elif c=="y":
        for i in m:
            if i==mo1[4][0]:
                m_shape = centroid1[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5, label="Fifth Motif")
            else:
                m_shape = centroid1[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5)
plt.legend()       
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 4>()
#      26         else:
#      27             m_shape = centroid1[i:i+w]
# ---> 28             plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5)
#      29 elif c=="b":
#      30     for i in m:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     495     self.axes.yaxis.update_units(y)
#     497 if x.shape[0] != y.shape[0]:
# --> 498     raise ValueError(f"x and y must have same first dimension, but "
#     499                      f"have shapes {x.shape} and {y.shape}")
#     500 if x.ndim > 2 or y.ndim > 2:
#     501     raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (7,)

# %% [markdown]
# ## Motif centroid 2

# %%
for w in range(3,11):
    mp2, mpi2 = matrixProfile.stomp(centroid2, w)
    plt.figure(figsize=(10,10))
    plt.plot(mp2)
    plt.ylabel("MatrixProfile value", fontsize=15)
    plt.text(0.95, 0.95, "Window size = "+str(w), fontsize=15, bbox=dict(facecolor="red", alpha=0.5), transform=plt.gca().transAxes, verticalalignment='top', horizontalalignment='right')
    plt.show()

# %%
w=7
mp1, mpi1 = matrixProfile.stomp(centroid2, w)
mo1, mod1  = motifs.motifs(centroid2, (mp1, mpi1), max_motifs=5)
print(mo1)
# Out:
# [[15, 32], [7, 25, 42], [2, 20, 37]]

# %%
for w in range(3,11):
    mp1, mpi1 = matrixProfile.stomp(centroid2, w)
    plt.figure(figsize=(10,10))
    plt.plot(mp1)
    plt.ylabel("MatrixProfile value", fontsize=15)
    plt.text(0.95, 0.95, "Window size = "+str(w), fontsize=15, bbox=dict(facecolor="red", alpha=0.5), transform=plt.gca().transAxes, verticalalignment='top', horizontalalignment='right')
    plt.show()

# %%
plt.figure(figsize=(10,10))
plt.plot(np.arange(1,len(centroid2)+1),centroid2)
colors = ['r', 'g', 'k', 'b', 'y'][:len(mo1)]
for m, d, c in zip(mo1, mod1, colors):
    if c=="r":
        for i in m:
            if i==mo1[0][0]:
                m_shape = centroid2[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5, label="First Motif")
            else:
                m_shape = centroid2[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5)                
    elif c=="g":
        for i in m:
            if i==mo1[1][0]:
                m_shape = centroid2[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5, label="Second Motif")
            else:
                m_shape = centroid2[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5) 
    elif c=="k":
        for i in m:
            if i==mo1[2][0]:
                m_shape = centroid2[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5, label="Third Motif")
            else:
                m_shape = centroid2[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5)
    elif c=="b":
        for i in m:
            if i==mo1[3][0]:
                m_shape = centroid2[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5, label="Fourth Motif")
            else:
                m_shape = centroid2[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5)
    elif c=="y":
        for i in m:
            if i==mo1[4][0]:
                m_shape = centroid2[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5, label="Fifth Motif")
            else:
                m_shape = centroid2[i:i+w]
                plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5)
plt.legend()       
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 4>()
#      18         else:
#      19             m_shape = centroid2[i:i+w]
# ---> 20             plt.plot(range(i+1,i+w+1), m_shape, color=c, lw=2.5)
#      21 elif c=="k":
#      22     for i in m:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     495     self.axes.yaxis.update_units(y)
#     497 if x.shape[0] != y.shape[0]:
# --> 498     raise ValueError(f"x and y must have same first dimension, but "
#     499                      f"have shapes {x.shape} and {y.shape}")
#     500 if x.ndim > 2 or y.ndim > 2:
#     501     raise ValueError(f"x and y can be no greater than 2D, but have "
#     502                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (10,) and (8,)

# %% [markdown]
# ## Anomaly centroid1_last

# %%
from matrixprofile.discords import discords

# %%
centroid1_last=np.load("kmeans_dtw_last_centroid.npy")

# %%
for w in range(3,11):
    mp1, mpi1 = matrixProfile.stomp(centroid1_last, w)
    plt.figure(figsize=(10,10))
    plt.plot(mp1)
    plt.ylabel("MatrixProfile value", fontsize=15)
    plt.text(0.95, 0.95, "Window size = "+str(w), fontsize=15, bbox=dict(facecolor="red", alpha=0.5), transform=plt.gca().transAxes, verticalalignment='top', horizontalalignment='right')
    plt.show()

# %%
w=5
mp1, mpi1 = matrixProfile.stomp(centroid1_last, w)
anoms1 = discords(mp1, ex_zone=3, k=5)
print(anoms1)

# %%
plt.figure(figsize=(10,10))
plt.plot(np.arange(1,len(centroid1_last)+1),centroid1_last)
colors = ['r', 'g', 'k', 'b', 'y'][:len(anoms1)]
for a, c in zip(anoms1, colors):
    if c=="r":
        a_shape = centroid1_last[a:a+w]
        plt.plot(range(a+1,a+w+1), a_shape, color=c, lw=2.5, label="First Discord")               
    if c=="g":
        a_shape = centroid1_last[a:a+w]
        plt.plot(range(a+1,a+w+1), a_shape, color=c, lw=2.5, label="Second Discord") 
    if c=="k":
        a_shape = centroid1_last[a:a+w]
        plt.plot(range(a+1,a+w+1), a_shape, color=c, lw=2.5, label="Third Discord")
    if c=="b":
        a_shape = centroid1_last[a:a+w]
        plt.plot(range(a+1,a+w+1), a_shape, color=c, lw=2.5, label="Fourth Discord")
    if c=="y":
        a_shape = centroid1_last[a:a+w]
        plt.plot(range(a+1,a+w+1), a_shape, color=c, lw=2.5, label="Fifth Discord")
plt.legend()       
plt.show()

# %% [markdown]
# ## anomaly centroid 2 last

# %%
centroid2_last=np.load("kmeans_dtw_2last_centroid.npy")

# %%
for w in range(3,11):
    mp1, mpi1 = matrixProfile.stomp(centroid2_last, w)
    plt.figure(figsize=(10,10))
    plt.plot(mp1)
    plt.ylabel("MatrixProfile value", fontsize=15)
    plt.text(0.95, 0.95, "Window size = "+str(w), fontsize=15, bbox=dict(facecolor="red", alpha=0.5), transform=plt.gca().transAxes, verticalalignment='top', horizontalalignment='right')
    plt.show()

# %%
w=5
mp1, mpi1 = matrixProfile.stomp(centroid2_last, w)
anoms1 = discords(mp1, ex_zone=3, k=5)
print(anoms1)

# %%
plt.figure(figsize=(10,10))
plt.plot(np.arange(1,len(centroid2_last)+1),centroid2_last)
colors = ['r', 'g', 'k', 'b', 'y'][:len(anoms1)]
for a, c in zip(anoms1, colors):
    if c=="r":
        a_shape = centroid2_last[a:a+w]
        plt.plot(range(a+1,a+w+1), a_shape, color=c, lw=2.5, label="First Discord")               
    if c=="g":
        a_shape = centroid2_last[a:a+w]
        plt.plot(range(a+1,a+w+1), a_shape, color=c, lw=2.5, label="Second Discord") 
    if c=="k":
        a_shape = centroid2_last[a:a+w]
        plt.plot(range(a+1,a+w+1), a_shape, color=c, lw=2.5, label="Third Discord")
    if c=="b":
        a_shape = centroid2_last[a:a+w]
        plt.plot(range(a+1,a+w+1), a_shape, color=c, lw=2.5, label="Fourth Discord")
    if c=="y":
        a_shape = centroid2_last[a:a+w]
        plt.plot(range(a+1,a+w+1), a_shape, color=c, lw=2.5, label="Fifth Discord")
plt.legend()       
plt.show()
