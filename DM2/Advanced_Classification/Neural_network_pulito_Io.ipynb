# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from collections import defaultdict

from sklearn.feature_selection import SelectKBest
from sklearn.preprocessing import StandardScaler

from sklearn.neural_network import MLPClassifier

from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.model_selection import RepeatedStratifiedKFold

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split

from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.metrics import log_loss

from tensorflow import keras

from keras.models import Sequential
from keras.layers import Dense, Dropout
from scikeras.wrappers import KerasClassifier
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.regularizers import l2
from tensorflow.keras.constraints import MaxNorm
# Out:
# 2023-04-29 16:52:13.125814: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core._multiarray_umath failed to import
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.umath failed to import
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core._multiarray_umath failed to import
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.umath failed to import
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# RuntimeError: module compiled against API version 0xf but this version of numpy is 0xe
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core._multiarray_umath failed to import
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: numpy.core.umath failed to import
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 21>()
#      18 from sklearn.metrics import roc_curve, auc, roc_auc_score
#      19 from sklearn.metrics import log_loss
# ---> 21 from tensorflow import keras
#      23 from keras.models import Sequential
#      24 from keras.layers import Dense, Dropout
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/__init__.py:37, in <module>
#      34 import sys as _sys
#      35 import typing as _typing
# ---> 37 from tensorflow.python.tools import module_util as _module_util
#      38 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      40 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/__init__.py:42, in <module>
#      37 from tensorflow.python.eager import context
#      39 # pylint: enable=wildcard-import
#      40
#      41 # Bring in subpackages.
# ---> 42 from tensorflow.python import data
#      43 from tensorflow.python import distribute
#      44 # from tensorflow.python import keras
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/__init__.py:21, in <module>
#      15 """`tf.data.Dataset` API for input pipelines.
#      16
#      17 See [Importing Data](https://tensorflow.org/guide/data) for an overview.
#      18 """
#      20 # pylint: disable=unused-import
# ---> 21 from tensorflow.python.data import experimental
#      22 from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
#      23 from tensorflow.python.data.ops.dataset_ops import Dataset
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/experimental/__init__.py:97, in <module>
#      15 """Experimental API for building input pipelines.
#      16
#      17 This module contains experimental `Dataset` sources and transformations that can
#    (...)
#      93 @@UNKNOWN_CARDINALITY
#      94 """
#      96 # pylint: disable=unused-import
# ---> 97 from tensorflow.python.data.experimental import service
#      98 from tensorflow.python.data.experimental.ops.batching import dense_to_ragged_batch
#      99 from tensorflow.python.data.experimental.ops.batching import dense_to_sparse_batch
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/experimental/service/__init__.py:419, in <module>
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """API for using the tf.data service.
#      16
#      17 This module contains:
#    (...)
#     416   job of ParameterServerStrategy).
#     417 """
# --> 419 from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#     420 from tensorflow.python.data.experimental.ops.data_service_ops import from_dataset_id
#     421 from tensorflow.python.data.experimental.ops.data_service_ops import register_dataset
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/experimental/ops/data_service_ops.py:22, in <module>
#      20 from tensorflow.core.protobuf import data_service_pb2
#      21 from tensorflow.python import tf2
# ---> 22 from tensorflow.python.data.experimental.ops import compression_ops
#      23 from tensorflow.python.data.experimental.service import _pywrap_server_lib
#      24 from tensorflow.python.data.experimental.service import _pywrap_utils
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/experimental/ops/compression_ops.py:16, in <module>
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Ops for compressing and uncompressing dataset elements."""
# ---> 16 from tensorflow.python.data.util import structure
#      17 from tensorflow.python.ops import gen_experimental_dataset_ops as ged_ops
#      20 def compress(element):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/util/structure.py:22, in <module>
#      18 import itertools
#      20 import wrapt
# ---> 22 from tensorflow.python.data.util import nest
#      23 from tensorflow.python.framework import composite_tensor
#      24 from tensorflow.python.framework import ops
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/data/util/nest.py:34, in <module>
#       1 # Copyright 2017 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      16 """## Functions for working with arbitrarily nested sequences of elements.
#      17
#      18 NOTE(mrry): This fork of the `tensorflow.python.util.nest` module
#    (...)
#      31    arrays.
#      32 """
# ---> 34 from tensorflow.python.framework import sparse_tensor as _sparse_tensor
#      35 from tensorflow.python.util import _pywrap_utils
#      36 from tensorflow.python.util import nest
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/sparse_tensor.py:25, in <module>
#      23 from tensorflow.python import tf2
#      24 from tensorflow.python.framework import composite_tensor
# ---> 25 from tensorflow.python.framework import constant_op
#      26 from tensorflow.python.framework import dtypes
#      27 from tensorflow.python.framework import ops
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:25, in <module>
#      23 from tensorflow.core.framework import types_pb2
#      24 from tensorflow.python.eager import context
# ---> 25 from tensorflow.python.eager import execute
#      26 from tensorflow.python.framework import dtypes
#      27 from tensorflow.python.framework import op_callbacks
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:21, in <module>
#      19 from tensorflow.python import pywrap_tfe
#      20 from tensorflow.python.eager import core
# ---> 21 from tensorflow.python.framework import dtypes
#      22 from tensorflow.python.framework import ops
#      23 from tensorflow.python.framework import tensor_shape
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/tensorflow/python/framework/dtypes.py:37, in <module>
#      34 from tensorflow.core.function import trace_type
#      35 from tensorflow.tools.docs import doc_controls
# ---> 37 _np_bfloat16 = _pywrap_bfloat16.TF_bfloat16_type()
#      38 _np_float8_e4m3fn = _pywrap_float8.TF_float8_e4m3fn_type()
#      39 _np_float8_e5m2 = _pywrap_float8.TF_float8_e5m2_type()
#
# TypeError: Unable to convert function return value to a Python type! The signature was
# 	() -> handle

# %%
import seaborn as sns
from sklearn.metrics import (
    accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix,
    roc_auc_score,
)
from scikitplot.metrics import plot_roc
from sklearn.metrics import roc_curve, auc, roc_auc_score
import time

# %%
df_train=pd.read_csv("../ravdess_features_train_pulito.csv")
df_test=pd.read_csv("../ravdess_features_test_pulito.csv")

df_train["emotion"]=df_train["emotion"].replace(["fearful", "angry", "happy", "surprised", "neutral", "calm", "sad", "disgust"],[0,1,2,3,4,5,6,7])
df_train["emotional_intensity"]=df_train["emotional_intensity"].replace(["normal", "strong"],[0,1])
df_train["sex"]=df_train["sex"].replace(["M", "F"],[0,1])
df_train["statement"]=df_train["statement"].replace(["Dogs are sitting by the door", "Kids are talking by the door"],[0,1])
df_train["vocal_channel"]=df_train["vocal_channel"].replace(["speech", "song"],[0,1])

df_test["emotion"]=df_test["emotion"].replace(["fearful", "angry", "happy", "surprised", "neutral", "calm", "sad", "disgust"],[0,1,2,3,4,5,6,7])
df_test["emotional_intensity"]=df_test["emotional_intensity"].replace(["normal", "strong"],[0,1])
df_test["sex"]=df_test["sex"].replace(["M", "F"],[0,1])
df_test["statement"]=df_test["statement"].replace(["Dogs are sitting by the door", "Kids are talking by the door"],[0,1])
df_test["vocal_channel"]=df_test["vocal_channel"].replace(["speech", "song"],[0,1])

# %% [markdown]
# ### Outliers dropping

# %%
#df_train.drop(axis="index", labels=[35,243,451,554,563,658,659,1031,1075,1283], inplace=True)
X_train=df_train.drop(columns=["emotion"]).values
y_train=df_train.emotion.values

#df_test.drop(axis="index", labels=[33,34,138,196,197,198,199], inplace=True)
X_test=df_test.drop(columns=["emotion"]).values
y_test=df_test.emotion.values

# %% [markdown]
# ### Features selection (da implementare)

# %%
sel = SelectKBest(k=108)
X_train_sel = sel.fit_transform(X_train, y_train)
X_test_sel = sel.transform(X_test)
# Out:
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:112: UserWarning: Features [108] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/feature_selection/_univariate_selection.py:113: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw

# %% [markdown]
# ### Scaling

# %%
scl = StandardScaler()
X_train = scl.fit_transform(X_train)
X_test = scl.transform(X_test)

# %%
X_test.shape
# Out:
# (624, 376)

# %% [markdown]
# # Multilayer Perceptron

# %% [markdown]
# ### Formula empirica 1

# %% [markdown]
# $size_{layer}=\sqrt{input*output}$ da cui per 2 layers:
#
# \begin{cases}
#     size_1 = \sqrt{input*size_2} \\
#     size_2 = \sqrt{size_1*output}
# \end{cases}
#
# risolvendo si ha:
#
# \begin{cases}
#     size_1 = (input^2*output)^{1/3} \\
#     size_2 = (input*output^2)^{1/3}
# \end{cases}

# %% [markdown]
# Per 2 layers:

# %%
layer_size_1 = ((X_train.shape[1]**2)*len(np.unique(y_train)))**(1/3)
layer_size_2 = ((X_train.shape[1])*len(np.unique(y_train))**2)**(1/3)
layer_size_1, layer_size_2
# Out:
# (104.1890054135137, 28.870608641109552)

# %%
clf = MLPClassifier(hidden_layer_sizes=(104,29), random_state=0, max_iter=1000)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.5224358974358975
# F1-score [0.44594595 0.66968326 0.47619048 0.53061224 0.48076923 0.57575758
#  0.36263736 0.61111111]
#               precision    recall  f1-score   support
#
#            0       0.63      0.34      0.45        96
#            1       0.59      0.77      0.67        96
#            2       0.48      0.47      0.48        96
#            3       0.52      0.54      0.53        48
#            4       0.45      0.52      0.48        48
#            5       0.56      0.59      0.58        96
#            6       0.38      0.34      0.36        96
#            7       0.55      0.69      0.61        48
#
#     accuracy                           0.52       624
#    macro avg       0.52      0.53      0.52       624
# weighted avg       0.52      0.52      0.51       624

# %% [markdown]
# Per un layer

# %%
layer_size = np.sqrt(X_train.shape[1]*len(np.unique(y_train)))
layer_size
# Out:
# 54.84523680320835

# %%
clf = MLPClassifier(hidden_layer_sizes=(55), random_state=0, max_iter=1000)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.5176282051282052
# F1-score [0.475      0.61818182 0.47761194 0.54       0.41758242 0.59512195
#  0.41463415 0.52336449]
#               precision    recall  f1-score   support
#
#            0       0.59      0.40      0.48        96
#            1       0.55      0.71      0.62        96
#            2       0.46      0.50      0.48        96
#            3       0.52      0.56      0.54        48
#            4       0.44      0.40      0.42        48
#            5       0.56      0.64      0.60        96
#            6       0.50      0.35      0.41        96
#            7       0.47      0.58      0.52        48
#
#     accuracy                           0.52       624
#    macro avg       0.51      0.52      0.51       624
# weighted avg       0.52      0.52      0.51       624

# %% [markdown]
# ### Formula empirica 2

# %% [markdown]
# $size_{layer} = \frac{2}{3}input + output$

# %%
layer_size = 2*X_train.shape[1]/3+len(np.unique(y_train))
layer_size
# Out:
# 258.66666666666663

# %%
clf = MLPClassifier(hidden_layer_sizes=(259), random_state=0, max_iter=1000)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.5256410256410257
# F1-score [0.46052632 0.68778281 0.45771144 0.52747253 0.44230769 0.6039604
#  0.35       0.5982906 ]
#               precision    recall  f1-score   support
#
#            0       0.62      0.36      0.46        96
#            1       0.61      0.79      0.69        96
#            2       0.44      0.48      0.46        96
#            3       0.56      0.50      0.53        48
#            4       0.41      0.48      0.44        48
#            5       0.58      0.64      0.60        96
#            6       0.44      0.29      0.35        96
#            7       0.51      0.73      0.60        48
#
#     accuracy                           0.53       624
#    macro avg       0.52      0.53      0.52       624
# weighted avg       0.53      0.53      0.51       624

# %% [markdown]
# ### Formula empirica 3

# %% [markdown]
# $size_{layer} = \frac{input+output}{2}$ da cui per 2 layers:
#
# \begin{cases}
#     size_1 = \frac{input+size_2}{2} \\
#     size_2 = \frac{size_1+output}{2}
# \end{cases}
#
# risolvendo si ha:
#
# \begin{cases}
#     size_1 = \frac{2}{3}input+\frac{1}{3}output \\
#     size_2 = \frac{1}{3}input+\frac{2}{3}output
# \end{cases}

# %% [markdown]
# Per 2 layers:

# %%
layer_size_1 = 2*X_train.shape[1]/3+len(np.unique(y_train))/3
layer_size_2 = X_train.shape[1]/3+2*len(np.unique(y_train))/3
layer_size_1, layer_size_2
# Out:
# (253.33333333333331, 130.66666666666666)

# %%
clf = MLPClassifier(hidden_layer_sizes=(253,131), random_state=0, max_iter=1000)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.530448717948718
# F1-score [0.50322581 0.68965517 0.49746193 0.52083333 0.36363636 0.60696517
#  0.36129032 0.54867257]
#               precision    recall  f1-score   support
#
#            0       0.66      0.41      0.50        96
#            1       0.59      0.83      0.69        96
#            2       0.49      0.51      0.50        96
#            3       0.52      0.52      0.52        48
#            4       0.35      0.38      0.36        48
#            5       0.58      0.64      0.61        96
#            6       0.47      0.29      0.36        96
#            7       0.48      0.65      0.55        48
#
#     accuracy                           0.53       624
#    macro avg       0.52      0.53      0.51       624
# weighted avg       0.53      0.53      0.52       624

# %% [markdown]
# Per 1 layer:

# %%
layer_size = (X_train.shape[1]+len(np.unique(y_train)))/2
layer_size
# Out:
# 192.0

# %%
clf = MLPClassifier(hidden_layer_sizes=(192), random_state=0, max_iter=1000)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.5208333333333334
# F1-score [0.47682119 0.65777778 0.49261084 0.54166667 0.3960396  0.61244019
#  0.32894737 0.54054054]
#               precision    recall  f1-score   support
#
#            0       0.65      0.38      0.48        96
#            1       0.57      0.77      0.66        96
#            2       0.47      0.52      0.49        96
#            3       0.54      0.54      0.54        48
#            4       0.38      0.42      0.40        48
#            5       0.57      0.67      0.61        96
#            6       0.45      0.26      0.33        96
#            7       0.48      0.62      0.54        48
#
#     accuracy                           0.52       624
#    macro avg       0.51      0.52      0.51       624
# weighted avg       0.52      0.52      0.51       624

# %%
plt.plot(clf.loss_curve_)
plt.show()

# %% [markdown]
# ### RandomSearchCV

# %%
'''
t1 = time.time()
param_grid = {
    "hidden_layer_sizes": [(104,29), (55), (259), (253,131), (192)],
    "activation": ["relu", "tanh", "logistic"],
    "alpha": np.linspace(0.001,0.005,num=10),
    #"momentum": np.linspace(0,1,num=11),
    "learning_rate_init": np.linspace(0.001,0.01,num=11)
}
grid = RandomizedSearchCV(
    MLPClassifier(solver="adam",learning_rate="adaptive"),
    param_distributions=param_grid,
    scoring="accuracy",
    cv=RepeatedStratifiedKFold(random_state=0),
    n_jobs=-1,
    n_iter=500,
)
grid.fit(X_train, y_train)
clf = grid.best_params_
t2 = time.time()
print("durata", t2-t1, "secondi")
'''
# Out:
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
#grid.best_params_

# %% [markdown]
# ### Best params: {'learning_rate_init': 0.0064,'hidden_layer_sizes': 259,'alpha': 0.003666666666666667,'activation': 'relu'}

# %%
Hid = [(104,29), (55), (259), (253,131), (192)]
Acc = []
F1s = []
for i in Hid:
    clf = MLPClassifier(activation="relu", early_stopping=True, hidden_layer_sizes=i, solver="adam", alpha=0.003666666666666667, learning_rate="adaptive", learning_rate_init=0.0064, random_state=0, max_iter=1000)

    clf.fit(X_train, y_train)

    y_pred = clf.predict(X_test)
    Acc.append(accuracy_score(y_test, y_pred))
    F1s.append(f1_score(y_test, y_pred, average=None))

#print('Accuracy %s' % accuracy_score(y_test, y_pred))
#print('F1-score %s' % f1_score(y_test, y_pred, average=None))
#print(classification_report(y_test, y_pred))

# %%
Acc
# Out:
# [0.47435897435897434,
#  0.5288461538461539,
#  0.5352564102564102,
#  0.5016025641025641,
#  0.5192307692307693]

# %%
clf = MLPClassifier(activation="relu", early_stopping=True, hidden_layer_sizes=(259), solver="adam", alpha=0.003666666666666667, learning_rate="adaptive", learning_rate_init=0.0064, random_state=0, max_iter=1000)

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy 0.5352564102564102
# F1-score [0.47798742 0.7        0.44221106 0.5106383  0.47524752 0.625
#  0.37179487 0.59459459]
#               precision    recall  f1-score   support
#
#            0       0.60      0.40      0.48        96
#            1       0.62      0.80      0.70        96
#            2       0.43      0.46      0.44        96
#            3       0.52      0.50      0.51        48
#            4       0.45      0.50      0.48        48
#            5       0.58      0.68      0.62        96
#            6       0.48      0.30      0.37        96
#            7       0.52      0.69      0.59        48
#
#     accuracy                           0.54       624
#    macro avg       0.53      0.54      0.52       624
# weighted avg       0.53      0.54      0.52       624

# %%
y_test_pred_proba = clf.predict_proba(X_test)

# %%
plot_roc(y_test, clf.predict_proba(X_test))
plt.show()
print(roc_auc_score(y_test, y_test_pred_proba, multi_class="ovr", average="macro"))
# Out:
# 0.8770653310448233

# %%
plt.plot(clf.validation_scores_)
plt.show()

# %% [markdown]
# ### Keras

# %%
def build_model():
    
    model = Sequential()
    model.add(Dense(X_train.shape[1], input_dim=X_train.shape[1], activation='relu', kernel_regularizer=l2(0.02)))
    model.add(Dropout(0.05))
    model.add(Dense(259, activation='relu', kernel_regularizer=l2(0.02), kernel_constraint=MaxNorm(3)))
    model.add(Dropout(0.05))
    model.add(Dense(8, activation='softmax', kernel_regularizer=l2(0.02), kernel_constraint=MaxNorm(3)))

    model.compile(loss='sparse_categorical_crossentropy', 
                  optimizer="adam", weighted_metrics=['accuracy'])
    return model

# %%
es = EarlyStopping(monitor='val_accuracy', patience=100, verbose=True)
mc = ModelCheckpoint('best_model_NOREG.h5', monitor='val_accuracy', save_best_only=True)
clf = KerasClassifier(build_fn=build_model, 
                      callbacks=[es],
                      batch_size=128, optimizer="adam", class_weight="balanced")

# %%
clf.fit(X_train, y_train, validation_split=0.2, epochs=500)
# Out:
# /Users/jacopogneri/opt/anaconda3/lib/python3.9/site-packages/scikeras/wrappers.py:301: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   warnings.warn(
# Epoch 1/500
# 12/12 [==============================] - 2s 54ms/step - loss: 14.5821 - accuracy: 0.3226 - val_loss: 12.8460 - val_accuracy: 0.4639
# Epoch 2/500
# 12/12 [==============================] - 0s 8ms/step - loss: 11.5196 - accuracy: 0.5551 - val_loss: 10.3878 - val_accuracy: 0.4266
# Epoch 3/500
# 12/12 [==============================] - 0s 8ms/step - loss: 9.1170 - accuracy: 0.6230 - val_loss: 8.3102 - val_accuracy: 0.4862
# Epoch 4/500
# 12/12 [==============================] - 0s 7ms/step - loss: 7.1952 - accuracy: 0.6731 - val_loss: 6.7131 - val_accuracy: 0.4794
# Epoch 5/500
# 12/12 [==============================] - 0s 8ms/step - loss: 5.7011 - accuracy: 0.7086 - val_loss: 5.5091 - val_accuracy: 0.4678
# Epoch 6/500
# 12/12 [==============================] - 0s 7ms/step - loss: 4.5854 - accuracy: 0.7055 - val_loss: 4.6085 - val_accuracy: 0.4375
# Epoch 7/500
# 12/12 [==============================] - 0s 7ms/step - loss: 3.7277 - accuracy: 0.7519 - val_loss: 3.9528 - val_accuracy: 0.4333
# Epoch 8/500
# 12/12 [==============================] - 0s 8ms/step - loss: 3.0949 - accuracy: 0.7698 - val_loss: 3.5149 - val_accuracy: 0.4114
# Epoch 9/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.6456 - accuracy: 0.7633 - val_loss: 3.1466 - val_accuracy: 0.4181
# Epoch 10/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.2953 - accuracy: 0.7709 - val_loss: 2.8081 - val_accuracy: 0.4952
# Epoch 11/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.0736 - accuracy: 0.7766 - val_loss: 2.6729 - val_accuracy: 0.4269
# Epoch 12/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.8913 - accuracy: 0.7905 - val_loss: 2.4851 - val_accuracy: 0.4730
# Epoch 13/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.7437 - accuracy: 0.7907 - val_loss: 2.4658 - val_accuracy: 0.4419
# Epoch 14/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.6304 - accuracy: 0.8146 - val_loss: 2.3965 - val_accuracy: 0.4239
# Epoch 15/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.5543 - accuracy: 0.8195 - val_loss: 2.3126 - val_accuracy: 0.4512
# Epoch 16/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.4936 - accuracy: 0.8289 - val_loss: 2.2578 - val_accuracy: 0.4667
# Epoch 17/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.4491 - accuracy: 0.8172 - val_loss: 2.2694 - val_accuracy: 0.4668
# Epoch 18/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.4299 - accuracy: 0.8194 - val_loss: 2.2016 - val_accuracy: 0.4884
# Epoch 19/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.4127 - accuracy: 0.8357 - val_loss: 2.2055 - val_accuracy: 0.4777
# Epoch 20/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3844 - accuracy: 0.8291 - val_loss: 2.2493 - val_accuracy: 0.4454
# Epoch 21/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3924 - accuracy: 0.8144 - val_loss: 2.2594 - val_accuracy: 0.4364
# Epoch 22/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3465 - accuracy: 0.8475 - val_loss: 2.2070 - val_accuracy: 0.4461
# Epoch 23/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3418 - accuracy: 0.8412 - val_loss: 2.1594 - val_accuracy: 0.4780
# Epoch 24/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3189 - accuracy: 0.8496 - val_loss: 2.2350 - val_accuracy: 0.4295
# Epoch 25/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3206 - accuracy: 0.8461 - val_loss: 2.2084 - val_accuracy: 0.4815
# Epoch 26/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3306 - accuracy: 0.8295 - val_loss: 2.2004 - val_accuracy: 0.4497
# Epoch 27/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3209 - accuracy: 0.8335 - val_loss: 2.2025 - val_accuracy: 0.4645
# Epoch 28/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.3276 - accuracy: 0.8280 - val_loss: 2.1797 - val_accuracy: 0.4409
# Epoch 29/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3283 - accuracy: 0.8179 - val_loss: 2.2626 - val_accuracy: 0.4737
# Epoch 30/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2999 - accuracy: 0.8569 - val_loss: 2.1089 - val_accuracy: 0.4996
# Epoch 31/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3085 - accuracy: 0.8324 - val_loss: 2.1506 - val_accuracy: 0.4868
# Epoch 32/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3112 - accuracy: 0.8306 - val_loss: 2.2578 - val_accuracy: 0.4230
# Epoch 33/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2990 - accuracy: 0.8403 - val_loss: 2.2219 - val_accuracy: 0.4359
# Epoch 34/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2998 - accuracy: 0.8514 - val_loss: 2.1422 - val_accuracy: 0.4969
# Epoch 35/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2919 - accuracy: 0.8429 - val_loss: 2.1635 - val_accuracy: 0.4507
# Epoch 36/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2960 - accuracy: 0.8378 - val_loss: 2.2616 - val_accuracy: 0.4499
# Epoch 37/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3308 - accuracy: 0.8130 - val_loss: 2.2573 - val_accuracy: 0.4235
# Epoch 38/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.3105 - accuracy: 0.8164 - val_loss: 2.2596 - val_accuracy: 0.4008
# Epoch 39/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2902 - accuracy: 0.8404 - val_loss: 2.2570 - val_accuracy: 0.4338
# Epoch 40/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2905 - accuracy: 0.8384 - val_loss: 2.1725 - val_accuracy: 0.4648
# Epoch 41/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2985 - accuracy: 0.8357 - val_loss: 2.3031 - val_accuracy: 0.4360
# Epoch 42/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2910 - accuracy: 0.8418 - val_loss: 2.2109 - val_accuracy: 0.4777
# Epoch 43/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2799 - accuracy: 0.8468 - val_loss: 2.1866 - val_accuracy: 0.4579
# Epoch 44/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2772 - accuracy: 0.8580 - val_loss: 2.2173 - val_accuracy: 0.4645
# Epoch 45/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2589 - accuracy: 0.8557 - val_loss: 2.1786 - val_accuracy: 0.4778
# Epoch 46/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2737 - accuracy: 0.8429 - val_loss: 2.2487 - val_accuracy: 0.4452
# Epoch 47/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2805 - accuracy: 0.8307 - val_loss: 2.1857 - val_accuracy: 0.4493
# Epoch 48/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2568 - accuracy: 0.8680 - val_loss: 2.2038 - val_accuracy: 0.4597
# Epoch 49/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2693 - accuracy: 0.8562 - val_loss: 2.2376 - val_accuracy: 0.4579
# Epoch 50/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2811 - accuracy: 0.8357 - val_loss: 2.2752 - val_accuracy: 0.4582
# Epoch 51/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2768 - accuracy: 0.8401 - val_loss: 2.2082 - val_accuracy: 0.4463
# Epoch 52/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2665 - accuracy: 0.8591 - val_loss: 2.1640 - val_accuracy: 0.4581
# Epoch 53/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2534 - accuracy: 0.8653 - val_loss: 2.1926 - val_accuracy: 0.4713
# Epoch 54/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2548 - accuracy: 0.8562 - val_loss: 2.2380 - val_accuracy: 0.4425
# Epoch 55/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2695 - accuracy: 0.8534 - val_loss: 2.2001 - val_accuracy: 0.4537
# Epoch 56/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2783 - accuracy: 0.8430 - val_loss: 2.1816 - val_accuracy: 0.4648
# Epoch 57/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2648 - accuracy: 0.8497 - val_loss: 2.1602 - val_accuracy: 0.4863
# Epoch 58/500
# 12/12 [==============================] - 0s 11ms/step - loss: 1.2595 - accuracy: 0.8536 - val_loss: 2.1537 - val_accuracy: 0.4671
# Epoch 59/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2671 - accuracy: 0.8485 - val_loss: 2.2202 - val_accuracy: 0.4719
# Epoch 60/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2806 - accuracy: 0.8319 - val_loss: 2.1561 - val_accuracy: 0.4757
# Epoch 61/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2740 - accuracy: 0.8501 - val_loss: 2.2264 - val_accuracy: 0.4667
# Epoch 62/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2710 - accuracy: 0.8368 - val_loss: 2.1734 - val_accuracy: 0.4451
# Epoch 63/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2575 - accuracy: 0.8563 - val_loss: 2.1844 - val_accuracy: 0.4714
# Epoch 64/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2669 - accuracy: 0.8463 - val_loss: 2.1256 - val_accuracy: 0.4859
# Epoch 65/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2574 - accuracy: 0.8568 - val_loss: 2.2641 - val_accuracy: 0.4489
# Epoch 66/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2520 - accuracy: 0.8440 - val_loss: 2.1182 - val_accuracy: 0.4846
# Epoch 67/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2570 - accuracy: 0.8546 - val_loss: 2.1526 - val_accuracy: 0.4755
# Epoch 68/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2537 - accuracy: 0.8496 - val_loss: 2.2559 - val_accuracy: 0.4531
# Epoch 69/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2803 - accuracy: 0.8237 - val_loss: 2.2932 - val_accuracy: 0.4223
# Epoch 70/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2600 - accuracy: 0.8395 - val_loss: 2.1843 - val_accuracy: 0.4776
# Epoch 71/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2517 - accuracy: 0.8552 - val_loss: 2.2466 - val_accuracy: 0.4561
# Epoch 72/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2378 - accuracy: 0.8630 - val_loss: 2.2763 - val_accuracy: 0.4537
# Epoch 73/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2533 - accuracy: 0.8535 - val_loss: 2.2073 - val_accuracy: 0.4628
# Epoch 74/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2471 - accuracy: 0.8631 - val_loss: 2.2090 - val_accuracy: 0.4666
# Epoch 75/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2771 - accuracy: 0.8289 - val_loss: 2.2759 - val_accuracy: 0.4574
# Epoch 76/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2728 - accuracy: 0.8298 - val_loss: 2.1620 - val_accuracy: 0.4468
# Epoch 77/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2643 - accuracy: 0.8401 - val_loss: 2.2658 - val_accuracy: 0.4251
# Epoch 78/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2493 - accuracy: 0.8480 - val_loss: 2.2842 - val_accuracy: 0.4032
# Epoch 79/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2507 - accuracy: 0.8569 - val_loss: 2.1425 - val_accuracy: 0.4730
# Epoch 80/500
# 12/12 [==============================] - 0s 10ms/step - loss: 1.2559 - accuracy: 0.8479 - val_loss: 2.2511 - val_accuracy: 0.4561
# Epoch 81/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2406 - accuracy: 0.8573 - val_loss: 2.1919 - val_accuracy: 0.4762
# Epoch 82/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2439 - accuracy: 0.8450 - val_loss: 2.1516 - val_accuracy: 0.4689
# Epoch 83/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2353 - accuracy: 0.8473 - val_loss: 2.2403 - val_accuracy: 0.4740
# Epoch 84/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2364 - accuracy: 0.8674 - val_loss: 2.2175 - val_accuracy: 0.4493
# Epoch 85/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2244 - accuracy: 0.8640 - val_loss: 2.1694 - val_accuracy: 0.4739
# Epoch 86/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2409 - accuracy: 0.8501 - val_loss: 2.1695 - val_accuracy: 0.4861
# Epoch 87/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2488 - accuracy: 0.8535 - val_loss: 2.2065 - val_accuracy: 0.4729
# Epoch 88/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2593 - accuracy: 0.8384 - val_loss: 2.2326 - val_accuracy: 0.4333
# Epoch 89/500
# 12/12 [==============================] - 0s 10ms/step - loss: 1.2421 - accuracy: 0.8619 - val_loss: 2.1593 - val_accuracy: 0.4813
# Epoch 90/500
# 12/12 [==============================] - 0s 10ms/step - loss: 1.2407 - accuracy: 0.8518 - val_loss: 2.1666 - val_accuracy: 0.4665
# Epoch 91/500
# 12/12 [==============================] - 0s 11ms/step - loss: 1.2480 - accuracy: 0.8539 - val_loss: 2.2767 - val_accuracy: 0.4223
# Epoch 92/500
# 12/12 [==============================] - 0s 12ms/step - loss: 1.2439 - accuracy: 0.8540 - val_loss: 2.0981 - val_accuracy: 0.4842
# Epoch 93/500
# 12/12 [==============================] - 0s 11ms/step - loss: 1.2421 - accuracy: 0.8625 - val_loss: 2.0976 - val_accuracy: 0.4757
# Epoch 94/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2538 - accuracy: 0.8412 - val_loss: 2.1409 - val_accuracy: 0.4822
# Epoch 95/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2317 - accuracy: 0.8679 - val_loss: 2.2785 - val_accuracy: 0.4451
# Epoch 96/500
# 12/12 [==============================] - 0s 10ms/step - loss: 1.2319 - accuracy: 0.8669 - val_loss: 2.1502 - val_accuracy: 0.4774
# Epoch 97/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2262 - accuracy: 0.8496 - val_loss: 2.2811 - val_accuracy: 0.4272
# Epoch 98/500
# 12/12 [==============================] - 0s 10ms/step - loss: 1.2316 - accuracy: 0.8608 - val_loss: 2.1474 - val_accuracy: 0.4561
# Epoch 99/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2192 - accuracy: 0.8719 - val_loss: 2.1676 - val_accuracy: 0.4753
# Epoch 100/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2058 - accuracy: 0.8764 - val_loss: 2.1844 - val_accuracy: 0.4533
# Epoch 101/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2158 - accuracy: 0.8759 - val_loss: 2.1897 - val_accuracy: 0.5127
# Epoch 102/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2353 - accuracy: 0.8529 - val_loss: 2.1947 - val_accuracy: 0.4579
# Epoch 103/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2345 - accuracy: 0.8618 - val_loss: 2.3061 - val_accuracy: 0.4296
# Epoch 104/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2459 - accuracy: 0.8413 - val_loss: 2.1949 - val_accuracy: 0.4782
# Epoch 105/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2407 - accuracy: 0.8480 - val_loss: 2.2244 - val_accuracy: 0.4556
# Epoch 106/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2309 - accuracy: 0.8573 - val_loss: 2.1556 - val_accuracy: 0.4713
# Epoch 107/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2339 - accuracy: 0.8663 - val_loss: 2.1378 - val_accuracy: 0.5102
# Epoch 108/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2171 - accuracy: 0.8686 - val_loss: 2.2427 - val_accuracy: 0.4517
# Epoch 109/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2250 - accuracy: 0.8541 - val_loss: 2.1968 - val_accuracy: 0.4821
# Epoch 110/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2289 - accuracy: 0.8524 - val_loss: 2.2123 - val_accuracy: 0.4753
# Epoch 111/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2251 - accuracy: 0.8625 - val_loss: 2.1512 - val_accuracy: 0.4714
# Epoch 112/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2341 - accuracy: 0.8470 - val_loss: 2.2213 - val_accuracy: 0.4631
# Epoch 113/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2283 - accuracy: 0.8695 - val_loss: 2.1516 - val_accuracy: 0.4824
# Epoch 114/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2470 - accuracy: 0.8476 - val_loss: 2.1588 - val_accuracy: 0.4836
# Epoch 115/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2351 - accuracy: 0.8681 - val_loss: 2.1460 - val_accuracy: 0.4692
# Epoch 116/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2299 - accuracy: 0.8590 - val_loss: 2.1808 - val_accuracy: 0.4491
# Epoch 117/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2530 - accuracy: 0.8318 - val_loss: 2.2265 - val_accuracy: 0.4602
# Epoch 118/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2381 - accuracy: 0.8603 - val_loss: 2.1584 - val_accuracy: 0.4795
# Epoch 119/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2533 - accuracy: 0.8385 - val_loss: 2.1706 - val_accuracy: 0.4426
# Epoch 120/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2342 - accuracy: 0.8496 - val_loss: 2.3044 - val_accuracy: 0.4383
# Epoch 121/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2214 - accuracy: 0.8603 - val_loss: 2.1967 - val_accuracy: 0.4537
# Epoch 122/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2224 - accuracy: 0.8713 - val_loss: 2.1851 - val_accuracy: 0.4491
# Epoch 123/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2277 - accuracy: 0.8558 - val_loss: 2.1695 - val_accuracy: 0.4539
# Epoch 124/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2203 - accuracy: 0.8651 - val_loss: 2.2267 - val_accuracy: 0.4598
# Epoch 125/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2206 - accuracy: 0.8691 - val_loss: 2.1597 - val_accuracy: 0.4885
# Epoch 126/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2092 - accuracy: 0.8724 - val_loss: 2.2396 - val_accuracy: 0.4470
# Epoch 127/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2285 - accuracy: 0.8606 - val_loss: 2.2087 - val_accuracy: 0.4668
# Epoch 128/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2115 - accuracy: 0.8678 - val_loss: 2.2467 - val_accuracy: 0.4389
# Epoch 129/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2177 - accuracy: 0.8702 - val_loss: 2.1547 - val_accuracy: 0.4692
# Epoch 130/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2249 - accuracy: 0.8648 - val_loss: 2.2194 - val_accuracy: 0.4574
# Epoch 131/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2216 - accuracy: 0.8629 - val_loss: 2.1965 - val_accuracy: 0.4667
# Epoch 132/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2119 - accuracy: 0.8707 - val_loss: 2.2040 - val_accuracy: 0.4471
# Epoch 133/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2181 - accuracy: 0.8680 - val_loss: 2.1596 - val_accuracy: 0.4732
# Epoch 134/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2154 - accuracy: 0.8656 - val_loss: 2.1629 - val_accuracy: 0.4648
# Epoch 135/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2014 - accuracy: 0.8825 - val_loss: 2.1829 - val_accuracy: 0.4579
# Epoch 136/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2216 - accuracy: 0.8641 - val_loss: 2.1068 - val_accuracy: 0.4996
# Epoch 137/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2238 - accuracy: 0.8641 - val_loss: 2.2334 - val_accuracy: 0.4687
# Epoch 138/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2157 - accuracy: 0.8597 - val_loss: 2.2352 - val_accuracy: 0.4450
# Epoch 139/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2138 - accuracy: 0.8719 - val_loss: 2.1345 - val_accuracy: 0.4931
# Epoch 140/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2066 - accuracy: 0.8741 - val_loss: 2.2653 - val_accuracy: 0.4713
# Epoch 141/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2125 - accuracy: 0.8707 - val_loss: 2.2291 - val_accuracy: 0.4560
# Epoch 142/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2243 - accuracy: 0.8590 - val_loss: 2.1973 - val_accuracy: 0.4695
# Epoch 143/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2212 - accuracy: 0.8586 - val_loss: 2.2051 - val_accuracy: 0.4822
# Epoch 144/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2266 - accuracy: 0.8529 - val_loss: 2.2043 - val_accuracy: 0.4847
# Epoch 145/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2242 - accuracy: 0.8602 - val_loss: 2.2125 - val_accuracy: 0.4709
# Epoch 146/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2255 - accuracy: 0.8596 - val_loss: 2.2101 - val_accuracy: 0.4604
# Epoch 147/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2187 - accuracy: 0.8548 - val_loss: 2.2284 - val_accuracy: 0.4600
# Epoch 148/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2068 - accuracy: 0.8725 - val_loss: 2.2669 - val_accuracy: 0.4315
# Epoch 149/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2229 - accuracy: 0.8569 - val_loss: 2.1681 - val_accuracy: 0.4799
# Epoch 150/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2125 - accuracy: 0.8746 - val_loss: 2.2201 - val_accuracy: 0.4513
# Epoch 151/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2128 - accuracy: 0.8654 - val_loss: 2.1202 - val_accuracy: 0.4932
# Epoch 152/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2113 - accuracy: 0.8669 - val_loss: 2.2888 - val_accuracy: 0.4203
# Epoch 153/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2155 - accuracy: 0.8707 - val_loss: 2.2235 - val_accuracy: 0.4713
# Epoch 154/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2017 - accuracy: 0.8702 - val_loss: 2.1872 - val_accuracy: 0.4600
# Epoch 155/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.1983 - accuracy: 0.8853 - val_loss: 2.2197 - val_accuracy: 0.4732
# Epoch 156/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1959 - accuracy: 0.8880 - val_loss: 2.1755 - val_accuracy: 0.4646
# Epoch 157/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2004 - accuracy: 0.8796 - val_loss: 2.3390 - val_accuracy: 0.4430
# Epoch 158/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2164 - accuracy: 0.8700 - val_loss: 2.1753 - val_accuracy: 0.4801
# Epoch 159/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2102 - accuracy: 0.8662 - val_loss: 2.2587 - val_accuracy: 0.4600
# Epoch 160/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2116 - accuracy: 0.8647 - val_loss: 2.1897 - val_accuracy: 0.4729
# Epoch 161/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2124 - accuracy: 0.8741 - val_loss: 2.1090 - val_accuracy: 0.5020
# Epoch 162/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2056 - accuracy: 0.8730 - val_loss: 2.1621 - val_accuracy: 0.4799
# Epoch 163/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2062 - accuracy: 0.8752 - val_loss: 2.1831 - val_accuracy: 0.4799
# Epoch 164/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1964 - accuracy: 0.8741 - val_loss: 2.1755 - val_accuracy: 0.4714
# Epoch 165/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1976 - accuracy: 0.8673 - val_loss: 2.1759 - val_accuracy: 0.4716
# Epoch 166/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2322 - accuracy: 0.8447 - val_loss: 2.1289 - val_accuracy: 0.4795
# Epoch 167/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2269 - accuracy: 0.8537 - val_loss: 2.1903 - val_accuracy: 0.4488
# Epoch 168/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2315 - accuracy: 0.8519 - val_loss: 2.1605 - val_accuracy: 0.4641
# Epoch 169/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2252 - accuracy: 0.8617 - val_loss: 2.1566 - val_accuracy: 0.4798
# Epoch 170/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2300 - accuracy: 0.8456 - val_loss: 2.2531 - val_accuracy: 0.4332
# Epoch 171/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2176 - accuracy: 0.8557 - val_loss: 2.1990 - val_accuracy: 0.4689
# Epoch 172/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2089 - accuracy: 0.8696 - val_loss: 2.1520 - val_accuracy: 0.4776
# Epoch 173/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2000 - accuracy: 0.8784 - val_loss: 2.1639 - val_accuracy: 0.4645
# Epoch 174/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.1994 - accuracy: 0.8697 - val_loss: 2.2099 - val_accuracy: 0.4692
# Epoch 175/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1949 - accuracy: 0.8790 - val_loss: 2.2347 - val_accuracy: 0.4515
# Epoch 176/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2029 - accuracy: 0.8680 - val_loss: 2.1634 - val_accuracy: 0.4777
# Epoch 177/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1999 - accuracy: 0.8801 - val_loss: 2.1556 - val_accuracy: 0.4603
# Epoch 178/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2124 - accuracy: 0.8758 - val_loss: 2.1823 - val_accuracy: 0.4801
# Epoch 179/500
# 12/12 [==============================] - 0s 10ms/step - loss: 1.2074 - accuracy: 0.8547 - val_loss: 2.3413 - val_accuracy: 0.4121
# Epoch 180/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2123 - accuracy: 0.8657 - val_loss: 2.1808 - val_accuracy: 0.4867
# Epoch 181/500
# 12/12 [==============================] - 0s 9ms/step - loss: 1.2423 - accuracy: 0.8475 - val_loss: 2.1868 - val_accuracy: 0.4737
# Epoch 182/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2379 - accuracy: 0.8429 - val_loss: 2.2249 - val_accuracy: 0.4540
# Epoch 183/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2324 - accuracy: 0.8408 - val_loss: 2.1998 - val_accuracy: 0.4456
# Epoch 184/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2234 - accuracy: 0.8447 - val_loss: 2.2487 - val_accuracy: 0.4297
# Epoch 185/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2210 - accuracy: 0.8574 - val_loss: 2.1986 - val_accuracy: 0.4604
# Epoch 186/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2165 - accuracy: 0.8592 - val_loss: 2.1869 - val_accuracy: 0.5016
# Epoch 187/500
# 12/12 [==============================] - 0s 8ms/step - loss: 1.2166 - accuracy: 0.8614 - val_loss: 2.2590 - val_accuracy: 0.4449
# Epoch 188/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2366 - accuracy: 0.8535 - val_loss: 2.2936 - val_accuracy: 0.4536
# Epoch 189/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2222 - accuracy: 0.8602 - val_loss: 2.1907 - val_accuracy: 0.4795
# Epoch 190/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2032 - accuracy: 0.8702 - val_loss: 2.1911 - val_accuracy: 0.4541
# Epoch 191/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2012 - accuracy: 0.8673 - val_loss: 2.1396 - val_accuracy: 0.4914
# Epoch 192/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2053 - accuracy: 0.8663 - val_loss: 2.1806 - val_accuracy: 0.4689
# Epoch 193/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2178 - accuracy: 0.8542 - val_loss: 2.1986 - val_accuracy: 0.4668
# Epoch 194/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.1950 - accuracy: 0.8757 - val_loss: 2.2162 - val_accuracy: 0.4604
# Epoch 195/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2025 - accuracy: 0.8774 - val_loss: 2.1927 - val_accuracy: 0.4779
# Epoch 196/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2023 - accuracy: 0.8713 - val_loss: 2.1366 - val_accuracy: 0.4817
# Epoch 197/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2052 - accuracy: 0.8714 - val_loss: 2.2125 - val_accuracy: 0.4689
# Epoch 198/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.2019 - accuracy: 0.8714 - val_loss: 2.2187 - val_accuracy: 0.4882
# Epoch 199/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1962 - accuracy: 0.8739 - val_loss: 2.2505 - val_accuracy: 0.4430
# Epoch 200/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.2092 - accuracy: 0.8652 - val_loss: 2.1537 - val_accuracy: 0.4778
# Epoch 201/500
# 12/12 [==============================] - 0s 7ms/step - loss: 1.1975 - accuracy: 0.8646 - val_loss: 2.2328 - val_accuracy: 0.4535
# Epoch 201: early stopping
# KerasClassifier(
# 	model=None
# 	build_fn=<function build_model at 0x7f89119aa4c0>
# 	warm_start=False
# 	random_state=None
# 	optimizer=adam
# 	loss=None
# 	metrics=None
# 	batch_size=128
# 	validation_batch_size=None
# 	verbose=1
# 	callbacks=[<keras.callbacks.EarlyStopping object at 0x7f89119bb8e0>]
# 	validation_split=0.0
# 	shuffle=True
# 	run_eagerly=False
# 	epochs=1
# 	class_weight=balanced
# )

# %%
history = clf.history_
plt.plot(history['accuracy'], label='Train')
plt.plot(history['val_accuracy'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history['loss'], label='Train')
plt.plot(history['val_loss'], label='Val')
plt.xlabel('Epochs')
plt.ylabel('Cross-Entropy')
plt.legend()
plt.show()

# %%
y_pred = clf.predict(X_test).astype(int)

print('Accuracy %s' % accuracy_score(y_test, y_pred))
print('F1-score %s' % f1_score(y_test, y_pred, average=None))
print(classification_report(y_test, y_pred))
# Out:
# 5/5 [==============================] - 0s 2ms/step
# Accuracy 0.5224358974358975
# F1-score [0.5060241  0.67755102 0.36363636 0.52336449 0.44       0.59701493
#  0.44318182 0.48484848]
#               precision    recall  f1-score   support
#
#            0       0.60      0.44      0.51        96
#            1       0.56      0.86      0.68        96
#            2       0.48      0.29      0.36        96
#            3       0.47      0.58      0.52        48
#            4       0.42      0.46      0.44        48
#            5       0.57      0.62      0.60        96
#            6       0.49      0.41      0.44        96
#            7       0.47      0.50      0.48        48
#
#     accuracy                           0.52       624
#    macro avg       0.51      0.52      0.50       624
# weighted avg       0.52      0.52      0.51       624
