# %% [markdown]
# This dataset was created from the RAVDESS dataset (https://es.sonicurlprotection-fra.com/click?PV=2&MSGID=202209141411100289250&URLID=1&ESV=10.0.18.7423&IV=CDD893A9D96AB6D6469DFBAF03B52C7A&TT=1663164671774&ESN=SJ44mpH7HPEgdwadIHqGKE9aHAKB%2FGfCfiESv9Jnnj4%3D&KV=1536961729280&B64_ENCODED_URL=aHR0cHM6Ly96ZW5vZG8ub3JnL3JlY29yZC8xMTg4OTc2KSw&HK=3428F8A9C48043894424396B826370722E127A5AEC482B778236DC3B3D0A300B extracting basic statistics (mean, std, min, max, etc.) from the original audio data and after transforming it using: zero-crossing rate, Mel-Frequency Cepstral Coefficients, spectral centroid, and the stft chromagram. Features were extracted from the 2452 wav files.
#
# Features:
#
# -modality (audio-only)
#
# -vocal_channel (speech, song)
#
# -emotion (neutral, calm, happy, sad, angry, fearful, disgust, surprised)
#
# -emotional_intensity (normal, strong). NOTE: There is no strong intensity for the 'neutral' emotion
#
# -statement ("Kids are talking by the door", "Dogs are sitting by the door")
#
# -repetition (1st repetition, 2nd repetition)
#
# -actor (01 to 24)
#
# -sex (M, F)
#
# -channels (number of channels; 1 for mono, 2 for stereo audio)
#
# -sample_width (number of bytes per sample; 1 means 8-bit, 2 means 16-bit)
#
# -frame_rate (frequency of samples used (in Hertz))
#
# -frame_width (Number of bytes for each âframeâ. One frame contains a sample for each channel.)
#
# -length_ms (audio file length (in milliseconds))
#
# -frame_count (the number of frames from the sample)
#
# -intensity (loudness in dBFS (dB relative to the maximum possible loudness))
#
# -zero_crossings_sum (sum of the zero-crossing rate)
#
# -'mean', 'std', 'min', 'max', 'kur', 'skew' (statistics of the original audio signal)
#
# -mfcc_ 'mean', 'std', 'min', 'max' (statistics of the Mel-Frequency Cepstral Coefficients)
#
# -sc_ 'mean', 'std', 'min', 'max', 'kur', 'skew' (statistics of the spectral centroid)
#
# -stft_ 'mean', 'std', 'min', 'max', 'kur', 'skew' (statistics of the stft chromagram)

# %%
import math
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

from collections import defaultdict
from scipy.stats.stats import pearsonr
from scipy.stats import shapiro
from scipy.stats import normaltest
from pandas.plotting import parallel_coordinates

# %%
df=pd.read_csv("ravdess_features.csv")

# %%
df
# Out:
#         modality vocal_channel    emotion emotional_intensity  \
# 0     audio-only        speech    fearful              normal
# 1     audio-only        speech      angry              normal
# 2     audio-only           NaN      happy              strong
# 3     audio-only           NaN  surprised              normal
# 4     audio-only          song      happy              strong
# ...          ...           ...        ...                 ...
# 2447  audio-only        speech       calm              strong
# 2448  audio-only        speech       calm              normal
# 2449  audio-only          song        sad              strong
# 2450  audio-only        speech  surprised              normal
# 2451  audio-only           NaN    neutral              normal
#
#                          statement repetition  actor sex  channels  \
# 0     Dogs are sitting by the door        2nd    2.0   F         1
# 1     Dogs are sitting by the door        1st   16.0   F         1
# 2     Dogs are sitting by the door        2nd   16.0   F         1
# 3     Kids are talking by the door        1st   14.0   F         1
# 4     Dogs are sitting by the door        2nd    2.0   F         1
# ...                            ...        ...    ...  ..       ...
# 2447  Kids are talking by the door        1st   23.0   M         1
# 2448  Dogs are sitting by the door        1st   23.0   M         1
# 2449  Dogs are sitting by the door        2nd   23.0   M         1
# 2450  Kids are talking by the door        1st    NaN   M         1
# 2451  Dogs are sitting by the door        2nd   23.0   M         1
#
#       sample_width  ...  stft_min  stft_max  stft_kur  stft_skew  \
# 0                2  ...  0.000000       1.0 -1.215025   0.403514
# 1                2  ...  0.000000       1.0 -1.384174   0.290905
# 2                2  ...  0.000000       1.0 -1.242947   0.470350
# 3                2  ...  0.000000       1.0 -1.445318   0.274756
# 4                2  ...  0.000000       1.0 -1.366742   0.318926
# ...            ...  ...       ...       ...       ...        ...
# 2447             2  ...  0.000000       1.0 -1.075888  -0.310088
# 2448             2  ...  0.000000       1.0 -1.026071  -0.408018
# 2449             2  ...  0.000000       1.0 -1.473789   0.130310
# 2450             2  ...  0.001565       1.0 -1.277117  -0.242668
# 2451             2  ...  0.000000       1.0 -1.257666  -0.237757
#
#               mean       std       min       max        kur      skew
# 0     3.844916e-07  0.014482 -0.128632  0.138947   9.406061  0.273153
# 1    -7.149491e-08  0.020417 -0.305725  0.263062  19.564187  0.292157
# 2     2.429985e-06  0.024317 -0.137482  0.166351   4.881241  0.302659
# 3     2.373929e-07  0.003561 -0.027374  0.024078  13.040259 -0.081014
# 4     8.454691e-07  0.027522 -0.192169  0.242676   7.485109  0.414872
# ...            ...       ...       ...       ...        ...       ...
# 2447  9.367040e-07  0.005260 -0.039856  0.052399   9.551363  0.759247
# 2448  4.614221e-07  0.006836 -0.064178  0.084045  22.517991  1.073633
# 2449 -8.219263e-06  0.015384 -0.093079  0.097260   4.964319 -0.005821
# 2450 -4.400898e-06  0.005182 -0.057556  0.052002  13.855588 -0.110966
# 2451  6.342640e-07  0.010001 -0.081512  0.103027  12.973181  1.032081
#
# [2452 rows x 38 columns]

# %%
df.dtypes
# Out:
# modality                object
# vocal_channel           object
# emotion                 object
# emotional_intensity     object
# statement               object
# repetition              object
# actor                  float64
# sex                     object
# channels                 int64
# sample_width             int64
# frame_rate               int64
# frame_width              int64
# length_ms                int64
# frame_count            float64
# intensity              float64
# zero_crossings_sum       int64
# mfcc_mean              float64
# mfcc_std               float64
# mfcc_min               float64
# mfcc_max               float64
# sc_mean                float64
# sc_std                 float64
# sc_min                 float64
# sc_max                 float64
# sc_kur                 float64
# sc_skew                float64
# stft_mean              float64
# stft_std               float64
# stft_min               float64
# stft_max               float64
# stft_kur               float64
# stft_skew              float64
# mean                   float64
# std                    float64
# min                    float64
# max                    float64
# kur                    float64
# skew                   float64
# dtype: object

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [modality, vocal_channel, emotion, emotional_intensity, statement, repetition, actor, sex, channels, sample_width, frame_rate, frame_width, length_ms, frame_count, intensity, zero_crossings_sum, mfcc_mean, mfcc_std, mfcc_min, mfcc_max, sc_mean, sc_std, sc_min, sc_max, sc_kur, sc_skew, stft_mean, stft_std, stft_min, stft_max, stft_kur, stft_skew, mean, std, min, max, kur, skew]
# Index: []
#
# [0 rows x 38 columns]

# %%
df=df.sort_values(by=["emotion"])
#print(df.to_string())

# %%
df.isna().sum()
# Out:
# modality                  0
# vocal_channel           196
# emotion                   0
# emotional_intensity       0
# statement                 0
# repetition                0
# actor                  1126
# sex                       0
# channels                  0
# sample_width              0
# frame_rate                0
# frame_width               0
# length_ms                 0
# frame_count               0
# intensity               816
# zero_crossings_sum        0
# mfcc_mean                 0
# mfcc_std                  0
# mfcc_min                  0
# mfcc_max                  0
# sc_mean                   0
# sc_std                    0
# sc_min                    0
# sc_max                    0
# sc_kur                    0
# sc_skew                   0
# stft_mean                 0
# stft_std                  0
# stft_min                  0
# stft_max                  0
# stft_kur                  0
# stft_skew                 0
# mean                      0
# std                       0
# min                       0
# max                       0
# kur                       0
# skew                      0
# dtype: int64

# %%
len(df[df["frame_count"]==-1])
# Out:
# 35

# %%
len(df[df["sc_min"]==0])
# Out:
# 1021

# %%
df.describe(include="all")
# Out:
#           modality vocal_channel emotion emotional_intensity  \
# count         2452          2256    2452                2452
# unique           1             2       8                   2
# top     audio-only        speech   angry              normal
# freq          2452          1335     376                1320
# mean           NaN           NaN     NaN                 NaN
# std            NaN           NaN     NaN                 NaN
# min            NaN           NaN     NaN                 NaN
# 25%            NaN           NaN     NaN                 NaN
# 50%            NaN           NaN     NaN                 NaN
# 75%            NaN           NaN     NaN                 NaN
# max            NaN           NaN     NaN                 NaN
#
#                            statement repetition        actor   sex  \
# count                           2452       2452  1326.000000  2452
# unique                             2          2          NaN     2
# top     Dogs are sitting by the door        1st          NaN     M
# freq                            1226       1226          NaN  1248
# mean                             NaN        NaN    12.582202   NaN
# std                              NaN        NaN     6.916240   NaN
# min                              NaN        NaN     1.000000   NaN
# 25%                              NaN        NaN     7.000000   NaN
# 50%                              NaN        NaN    13.000000   NaN
# 75%                              NaN        NaN    19.000000   NaN
# max                              NaN        NaN    24.000000   NaN
#
#            channels  sample_width  ...     stft_min  stft_max     stft_kur  \
# count   2452.000000        2452.0  ...  2452.000000    2452.0  2452.000000
# unique          NaN           NaN  ...          NaN       NaN          NaN
# top             NaN           NaN  ...          NaN       NaN          NaN
# freq            NaN           NaN  ...          NaN       NaN          NaN
# mean       1.002447           2.0  ...     0.002272       1.0    -1.247929
# std        0.049416           0.0  ...     0.004830       0.0     0.211781
# min        1.000000           2.0  ...     0.000000       1.0    -1.669603
# 25%        1.000000           2.0  ...     0.000000       1.0    -1.390612
# 50%        1.000000           2.0  ...     0.000190       1.0    -1.292105
# 75%        1.000000           2.0  ...     0.001999       1.0    -1.152519
# max        2.000000           2.0  ...     0.039378       1.0     0.794669
#
#           stft_skew          mean          std          min          max  \
# count   2452.000000  2.452000e+03  2452.000000  2452.000000  2452.000000
# unique          NaN           NaN          NaN          NaN          NaN
# top             NaN           NaN          NaN          NaN          NaN
# freq            NaN           NaN          NaN          NaN          NaN
# mean       0.112889  1.393649e-08     0.020504    -0.164871     0.179839
# std        0.330759  4.267587e-05     0.021024     0.175443     0.195539
# min       -0.993957 -9.435575e-04     0.000652    -0.998810     0.004669
# 25%       -0.094334 -1.394488e-06     0.006791    -0.202431     0.055489
# 50%        0.126065 -9.810701e-08     0.013880    -0.103775     0.109726
# 75%        0.335574  8.363511e-07     0.026154    -0.054352     0.224487
# max        1.465815  1.222810e-03     0.152168    -0.006134     0.999146
#
#                 kur         skew
# count   2452.000000  2452.000000
# unique          NaN          NaN
# top             NaN          NaN
# freq            NaN          NaN
# mean      11.203002    -0.048245
# std        6.614859     0.454925
# min        1.757794    -2.356526
# 25%        6.519988    -0.336624
# 50%        9.828686     0.004256
# 75%       14.085435     0.262978
# max       59.085695     1.799676
#
# [11 rows x 38 columns]

# %% [markdown]
# ### Filling missing values

# %%
df["emotion"]=df["emotion"].replace(["fearful", "angry", "happy", "surprised", "neutral", "calm", "sad", "disgust"],[0,1,2,3,4,5,6,7])
df["emotional_intensity"]=df["emotional_intensity"].replace(["normal", "strong"],[0,1])
df["vocal_channel"]=df["vocal_channel"].replace(["speech", "song"],[0,1])
df["repetition"]=df["repetition"].replace(["1st", "2nd"],[0,1])
df["sex"]=df["sex"].replace(["M", "F"],[0,1])
df["statement"]=df["statement"].replace(["Dogs are sitting by the door", "Kids are talking by the door"],[0,1])
df.drop(columns=["sample_width", "frame_rate", "stft_max"]).corr().style.background_gradient(cmap="coolwarm", vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_c0718_row0_col0, #T_c0718_row1_col1, #T_c0718_row2_col2, #T_c0718_row3_col3, #T_c0718_row4_col4, #T_c0718_row5_col5, #T_c0718_row6_col6, #T_c0718_row7_col7, #T_c0718_row7_col8, #T_c0718_row8_col7, #T_c0718_row8_col8, #T_c0718_row9_col9, #T_c0718_row10_col10, #T_c0718_row11_col11, #T_c0718_row12_col12, #T_c0718_row13_col13, #T_c0718_row14_col14, #T_c0718_row15_col15, #T_c0718_row16_col16, #T_c0718_row17_col17, #T_c0718_row18_col18, #T_c0718_row19_col19, #T_c0718_row20_col20, #T_c0718_row21_col21, #T_c0718_row22_col22, #T_c0718_row23_col23, #T_c0718_row24_col24, #T_c0718_row25_col25, #T_c0718_row26_col26, #T_c0718_row27_col27, #T_c0718_row28_col28, #T_c0718_row29_col29, #T_c0718_row30_col30, #T_c0718_row31_col31, #T_c0718_row32_col32, #T_c0718_row33_col33 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c0718_row0_col1, #T_c0718_row0_col26, #T_c0718_row1_col0, #T_c0718_row2_col17, #T_c0718_row6_col32, #T_c0718_row9_col20, #T_c0718_row12_col32, #T_c0718_row17_col2, #T_c0718_row20_col9, #T_c0718_row26_col0, #T_c0718_row32_col6, #T_c0718_row32_col12 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_c0718_row0_col2, #T_c0718_row0_col5, #T_c0718_row2_col0, #T_c0718_row3_col15, #T_c0718_row3_col19, #T_c0718_row4_col17, #T_c0718_row4_col18, #T_c0718_row4_col20, #T_c0718_row4_col23, #T_c0718_row4_col30, #T_c0718_row5_col0, #T_c0718_row5_col14, #T_c0718_row5_col30, #T_c0718_row6_col28, #T_c0718_row7_col9, #T_c0718_row8_col9, #T_c0718_row9_col7, #T_c0718_row9_col8, #T_c0718_row14_col5, #T_c0718_row15_col3, #T_c0718_row15_col32, #T_c0718_row17_col4, #T_c0718_row17_col26, #T_c0718_row18_col4, #T_c0718_row18_col28, #T_c0718_row19_col3, #T_c0718_row20_col4, #T_c0718_row20_col23, #T_c0718_row23_col4, #T_c0718_row23_col20, #T_c0718_row26_col17, #T_c0718_row28_col6, #T_c0718_row28_col18, #T_c0718_row28_col29, #T_c0718_row28_col32, #T_c0718_row28_col33, #T_c0718_row29_col28, #T_c0718_row30_col4, #T_c0718_row30_col5, #T_c0718_row32_col15, #T_c0718_row32_col28, #T_c0718_row33_col28 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_c0718_row0_col3, #T_c0718_row1_col7, #T_c0718_row1_col8, #T_c0718_row3_col0, #T_c0718_row3_col6, #T_c0718_row3_col16, #T_c0718_row3_col23, #T_c0718_row3_col25, #T_c0718_row3_col28, #T_c0718_row4_col5, #T_c0718_row4_col16, #T_c0718_row4_col26, #T_c0718_row4_col28, #T_c0718_row4_col33, #T_c0718_row5_col4, #T_c0718_row6_col3, #T_c0718_row6_col22, #T_c0718_row7_col1, #T_c0718_row7_col10, #T_c0718_row7_col25, #T_c0718_row8_col1, #T_c0718_row8_col10, #T_c0718_row8_col25, #T_c0718_row10_col7, #T_c0718_row10_col8, #T_c0718_row14_col28, #T_c0718_row15_col28, #T_c0718_row16_col3, #T_c0718_row16_col4, #T_c0718_row17_col28, #T_c0718_row18_col32, #T_c0718_row19_col28, #T_c0718_row22_col6, #T_c0718_row23_col3, #T_c0718_row24_col28, #T_c0718_row25_col3, #T_c0718_row25_col7, #T_c0718_row25_col8, #T_c0718_row26_col4, #T_c0718_row28_col3, #T_c0718_row28_col4, #T_c0718_row28_col14, #T_c0718_row28_col15, #T_c0718_row28_col17, #T_c0718_row28_col19, #T_c0718_row28_col24, #T_c0718_row28_col30, #T_c0718_row30_col28, #T_c0718_row32_col18, #T_c0718_row33_col4 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_c0718_row0_col4, #T_c0718_row1_col3, #T_c0718_row1_col4, #T_c0718_row1_col6, #T_c0718_row1_col32, #T_c0718_row2_col3, #T_c0718_row2_col4, #T_c0718_row2_col6, #T_c0718_row2_col26, #T_c0718_row3_col1, #T_c0718_row3_col2, #T_c0718_row3_col4, #T_c0718_row3_col5, #T_c0718_row3_col7, #T_c0718_row3_col8, #T_c0718_row3_col20, #T_c0718_row3_col30, #T_c0718_row3_col31, #T_c0718_row4_col0, #T_c0718_row4_col1, #T_c0718_row4_col2, #T_c0718_row4_col3, #T_c0718_row4_col6, #T_c0718_row4_col21, #T_c0718_row4_col24, #T_c0718_row4_col25, #T_c0718_row5_col3, #T_c0718_row6_col1, #T_c0718_row6_col2, #T_c0718_row6_col4, #T_c0718_row6_col7, #T_c0718_row6_col8, #T_c0718_row7_col3, #T_c0718_row7_col6, #T_c0718_row7_col28, #T_c0718_row8_col3, #T_c0718_row8_col6, #T_c0718_row8_col28, #T_c0718_row9_col28, #T_c0718_row10_col13, #T_c0718_row13_col10, #T_c0718_row13_col28, #T_c0718_row16_col20, #T_c0718_row20_col3, #T_c0718_row20_col16, #T_c0718_row21_col4, #T_c0718_row22_col28, #T_c0718_row24_col4, #T_c0718_row25_col4, #T_c0718_row26_col2, #T_c0718_row26_col27, #T_c0718_row27_col26, #T_c0718_row28_col7, #T_c0718_row28_col8, #T_c0718_row28_col9, #T_c0718_row28_col13, #T_c0718_row28_col22, #T_c0718_row30_col3, #T_c0718_row31_col3, #T_c0718_row32_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_c0718_row0_col6, #T_c0718_row0_col7, #T_c0718_row0_col8, #T_c0718_row0_col30, #T_c0718_row1_col2, #T_c0718_row1_col28, #T_c0718_row2_col1, #T_c0718_row3_col29, #T_c0718_row4_col32, #T_c0718_row5_col16, #T_c0718_row5_col32, #T_c0718_row6_col0, #T_c0718_row7_col0, #T_c0718_row7_col27, #T_c0718_row8_col0, #T_c0718_row8_col27, #T_c0718_row16_col5, #T_c0718_row26_col28, #T_c0718_row27_col7, #T_c0718_row27_col8, #T_c0718_row28_col1, #T_c0718_row28_col26, #T_c0718_row29_col3, #T_c0718_row30_col0, #T_c0718_row32_col4, #T_c0718_row32_col5 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_c0718_row0_col9, #T_c0718_row9_col0 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_c0718_row0_col10, #T_c0718_row10_col0, #T_c0718_row18_col20, #T_c0718_row20_col18 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_c0718_row0_col11, #T_c0718_row11_col0, #T_c0718_row13_col23, #T_c0718_row23_col13 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_c0718_row0_col12, #T_c0718_row12_col0, #T_c0718_row23_col30, #T_c0718_row30_col23 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_c0718_row0_col13, #T_c0718_row5_col9, #T_c0718_row5_col10, #T_c0718_row5_col15, #T_c0718_row6_col17, #T_c0718_row9_col5, #T_c0718_row10_col5, #T_c0718_row10_col31, #T_c0718_row13_col0, #T_c0718_row15_col5, #T_c0718_row17_col6, #T_c0718_row31_col10, #T_c0718_row32_col33, #T_c0718_row33_col32 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_c0718_row0_col14, #T_c0718_row0_col16, #T_c0718_row14_col0, #T_c0718_row16_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_c0718_row0_col15, #T_c0718_row2_col22, #T_c0718_row6_col20, #T_c0718_row12_col33, #T_c0718_row13_col25, #T_c0718_row15_col0, #T_c0718_row18_col24, #T_c0718_row20_col6, #T_c0718_row22_col2, #T_c0718_row24_col18, #T_c0718_row25_col13, #T_c0718_row33_col12 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_c0718_row0_col17, #T_c0718_row0_col32, #T_c0718_row16_col27, #T_c0718_row17_col0, #T_c0718_row27_col16, #T_c0718_row32_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_c0718_row0_col18, #T_c0718_row1_col12, #T_c0718_row1_col22, #T_c0718_row12_col1, #T_c0718_row18_col0, #T_c0718_row22_col1, #T_c0718_row23_col31, #T_c0718_row31_col23 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_c0718_row0_col19, #T_c0718_row2_col7, #T_c0718_row2_col8, #T_c0718_row5_col19, #T_c0718_row5_col23, #T_c0718_row7_col2, #T_c0718_row7_col12, #T_c0718_row7_col15, #T_c0718_row7_col21, #T_c0718_row8_col2, #T_c0718_row8_col12, #T_c0718_row8_col15, #T_c0718_row8_col21, #T_c0718_row10_col30, #T_c0718_row12_col7, #T_c0718_row12_col8, #T_c0718_row12_col20, #T_c0718_row15_col7, #T_c0718_row15_col8, #T_c0718_row19_col0, #T_c0718_row19_col5, #T_c0718_row20_col12, #T_c0718_row21_col7, #T_c0718_row21_col8, #T_c0718_row22_col26, #T_c0718_row23_col5, #T_c0718_row26_col22, #T_c0718_row30_col10 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_c0718_row0_col20, #T_c0718_row5_col21, #T_c0718_row6_col26, #T_c0718_row14_col19, #T_c0718_row19_col14, #T_c0718_row20_col0, #T_c0718_row21_col5, #T_c0718_row25_col31, #T_c0718_row26_col6, #T_c0718_row30_col32, #T_c0718_row31_col25, #T_c0718_row32_col30 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_c0718_row0_col21, #T_c0718_row1_col18, #T_c0718_row2_col12, #T_c0718_row11_col24, #T_c0718_row12_col2, #T_c0718_row13_col22, #T_c0718_row18_col1, #T_c0718_row21_col0, #T_c0718_row22_col13, #T_c0718_row24_col11 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_c0718_row0_col22, #T_c0718_row6_c

# %%
df["vocal_channel_fill1"]=df["vocal_channel"]
df["vocal_channel_fill1"]=df["vocal_channel_fill1"].groupby([df["emotion"], df["emotional_intensity"]]).apply(lambda x: x.fillna(x.mode()[0]))
df["vocal_channel"]=df["vocal_channel"].replace([0,1],["speech", "song"])
df["vocal_channel_fill1"]=df["vocal_channel_fill1"].replace([0,1],["speech", "song"])

# %%
df["vocal_channel"].count()
# Out:
# 2256

# %%
df["vocal_channel_fill1"].count()
# Out:
# 2452

# %%
df[(df["vocal_channel_fill1"]!="speech") & (df["vocal_channel_fill1"]!="song")]
# Out:
# Empty DataFrame
# Columns: [modality, vocal_channel, emotion, emotional_intensity, statement, repetition, actor, sex, channels, sample_width, frame_rate, frame_width, length_ms, frame_count, intensity, zero_crossings_sum, mfcc_mean, mfcc_std, mfcc_min, mfcc_max, sc_mean, sc_std, sc_min, sc_max, sc_kur, sc_skew, stft_mean, stft_std, stft_min, stft_max, stft_kur, stft_skew, mean, std, min, max, kur, skew, vocal_channel_fill1]
# Index: []
#
# [0 rows x 39 columns]

# %%
fig, axes=plt.subplots(2, figsize=(10,10))
sns.histplot(data=df, x="vocal_channel", ax=axes[0])
sns.histplot(data=df, x="vocal_channel_fill1", ax=axes[1])
fig.show()
# Out:
# /tmp/ipykernel_5181/3208566856.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df["intensity_fill1"]=df["intensity"]
df["intensity_fill1"]=df["intensity_fill1"].groupby([df["emotion"], df["emotional_intensity"]]).apply(lambda x: x.fillna(x.mean()))

# %%
df["intensity"].count()
# Out:
# 1636

# %%
df["intensity_fill1"].count()
# Out:
# 2452

# %%
fig, axes=plt.subplots(2, figsize=(10,10))
sns.histplot(data=df, x="intensity", ax=axes[0])
sns.histplot(data=df, x="intensity_fill1", ax=axes[1])
fig.show()
# Out:
# /tmp/ipykernel_5181/1396965744.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df["frame_count_fill"]=df["frame_count"]
df["frame_count_fill"]=df["frame_count_fill"].groupby([df["emotion"], df["emotional_intensity"]]).apply(lambda x: x.fillna(x.mean()))

# %%
#variabili correlate più interessanti
df.corr().loc[["intensity_fill1", "sex", "emotion", "emotional_intensity", "mfcc_std", "mfcc_min", "sc_mean", "sc_std", "sc_kur", "sc_skew", "stft_mean", "stft_std", "stft_skew", "std", "min", "max"], ["intensity_fill1", "sex", "emotion", "emotional_intensity", "mfcc_std", "mfcc_min", "sc_mean", "sc_std", "sc_kur", "sc_skew", "stft_mean", "stft_std", "stft_skew", "std", "min", "max"]].style.background_gradient(cmap="coolwarm", vmin=-1, vmax=1)
# Out:
# <style type="text/css">
# #T_70608_row0_col0, #T_70608_row1_col1, #T_70608_row2_col2, #T_70608_row3_col3, #T_70608_row4_col4, #T_70608_row5_col5, #T_70608_row6_col6, #T_70608_row7_col7, #T_70608_row8_col8, #T_70608_row9_col9, #T_70608_row10_col10, #T_70608_row11_col11, #T_70608_row12_col12, #T_70608_row13_col13, #T_70608_row14_col14, #T_70608_row15_col15 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_70608_row0_col1, #T_70608_row1_col0, #T_70608_row2_col10, #T_70608_row10_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_70608_row0_col2, #T_70608_row2_col0 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_70608_row0_col3, #T_70608_row3_col0, #T_70608_row3_col5, #T_70608_row3_col13, #T_70608_row5_col3, #T_70608_row13_col3 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_70608_row0_col4, #T_70608_row4_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_70608_row0_col5, #T_70608_row5_col0 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_70608_row0_col6, #T_70608_row6_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_70608_row0_col7, #T_70608_row4_col12, #T_70608_row7_col0, #T_70608_row7_col15, #T_70608_row12_col4, #T_70608_row15_col7 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_70608_row0_col8, #T_70608_row8_col0, #T_70608_row8_col15, #T_70608_row15_col8 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_70608_row0_col9, #T_70608_row9_col0 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_70608_row0_col10, #T_70608_row10_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_70608_row0_col11, #T_70608_row3_col9, #T_70608_row7_col11, #T_70608_row9_col3, #T_70608_row11_col0, #T_70608_row11_col7 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_70608_row0_col12, #T_70608_row12_col0 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_70608_row0_col13, #T_70608_row13_col0 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_70608_row0_col14, #T_70608_row14_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_70608_row0_col15, #T_70608_row15_col0 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_70608_row1_col2, #T_70608_row1_col3, #T_70608_row2_col1, #T_70608_row3_col1 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_70608_row1_col4, #T_70608_row4_col1 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_70608_row1_col5, #T_70608_row5_col1 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_70608_row1_col6, #T_70608_row6_col1 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_70608_row1_col7, #T_70608_row7_col1 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_70608_row1_col8, #T_70608_row8_col1 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_70608_row1_col9, #T_70608_row9_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_70608_row1_col10, #T_70608_row10_col1 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_70608_row1_col11, #T_70608_row11_col1 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_70608_row1_col12, #T_70608_row12_col1 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_70608_row1_col13, #T_70608_row13_col1 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_70608_row1_col14, #T_70608_row11_col14, #T_70608_row14_col1, #T_70608_row14_col11 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_70608_row1_col15, #T_70608_row11_col15, #T_70608_row15_col1, #T_70608_row15_col11 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_70608_row2_col3, #T_70608_row3_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_70608_row2_col4, #T_70608_row4_col2 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_70608_row2_col5, #T_70608_row5_col2 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_70608_row2_col6, #T_70608_row6_col2, #T_70608_row7_col10, #T_70608_row10_col7 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_70608_row2_col7, #T_70608_row7_col2 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_70608_row2_col8, #T_70608_row7_col12, #T_70608_row8_col2, #T_70608_row10_col13, #T_70608_row12_col7, #T_70608_row13_col10 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_70608_row2_col9, #T_70608_row9_col2, #T_70608_row10_col15, #T_70608_row15_col10 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_70608_row2_col11, #T_70608_row11_col2 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_70608_row2_col12, #T_70608_row3_col10, #T_70608_row10_col3, #T_70608_row12_col2 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_70608_row2_col13, #T_70608_row13_col2 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_70608_row2_col14, #T_70608_row14_col2 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_70608_row2_col15, #T_70608_row4_col8, #T_70608_row5_col7, #T_70608_row7_col5, #T_70608_row8_col4, #T_70608_row15_col2 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_70608_row3_col4, #T_70608_row3_col14, #T_70608_row4_col3, #T_70608_row14_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_70608_row3_col6, #T_70608_row6_col3 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_70608_row3_col7, #T_70608_row7_col3 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_70608_row3_col8, #T_70608_row8_col3 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_70608_row3_col11, #T_70608_row11_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_70608_row3_col12, #T_70608_row12_col3 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_70608_row3_col15, #T_70608_row15_col3 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_70608_row4_col5, #T_70608_row5_col4, #T_70608_row10_col12, #T_70608_row12_col10 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_70608_row4_col6, #T_70608_row5_col8, #T_70608_row6_col4, #T_70608_row8_col5, #T_70608_row8_col13, #T_70608_row9_col11, #T_70608_row11_col9, #T_70608_row13_col8 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_70608_row4_col7, #T_70608_row6_col7, #T_70608_row7_col4, #T_70608_row7_col6 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_70608_row4_col9, #T_70608_row9_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_70608_row4_col10, #T_70608_row5_col9, #T_70608_row9_col5, #T_70608_row10_col4 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_70608_row4_col11, #T_70608_row11_col4 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_70608_row4_col13, #T_70608_row13_col4 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_70608_row4_col14, #T_70608_row14_col4 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_70608_row4_col15, #T_70608_row15_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_70608_row5_col6, #T_70608_row6_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_70608_row5_col10, #T_70608_row10_col5 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_70608_row5_col11, #T_70608_row11_col5 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_70608_row5_col12, #T_70608_row9_col13, #T_70608_row12_col5, #T_70608_row13_col9 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_70608_row5_col13, #T_70608_row13_col5 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_70608_row5_col14, #T_70608_row14_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_70608_row5_col15, #T_70608_row15_col5 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_70608_row6_col8, #T_70608_row8_col6 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_70608_row6_col9, #T_70608_row9_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_70608_row6_col10, #T_70608_row10_col6 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_70608_row6_col11, #T_70608_row11_col6 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_70608_row6_col12, #T_70608_row12_col6 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_70608_row6_col13, #T_70608_row13_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_70608_row6_col14, #T_70608_row12_col15, #T_70608_row14_col6, #T_70608_row15_col12 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_70608_row6_col15, #T_70608_row12_col14, #T_70608_row14_col12, #T_70608_row15_col6 {
#   bac

# %% [markdown]
# # Distribuzioni e Outliers

# %%
#istogrammi divisi per genere
fig, axs=plt.subplots(4,4,figsize=(15,15))
sns.histplot(data=df, x="emotion", hue="sex", ax=axs[0][0])
sns.histplot(data=df, x="emotional_intensity", hue="sex", ax=axs[1][0])
sns.histplot(data=df, x="statement", hue="sex", ax=axs[2][0])
sns.histplot(data=df, x="repetition", hue="sex", ax=axs[3][0])
sns.histplot(data=df, x="length_ms", hue="sex", ax=axs[0][1])
sns.histplot(data=df, x="frame_count", hue="sex", ax=axs[0][2])
sns.histplot(data=df, x="intensity", hue="sex", ax=axs[0][3])
sns.histplot(data=df, x="zero_crossings_sum", hue="sex", ax=axs[1][1])
sns.histplot(data=df, x="mfcc_mean", hue="sex", ax=axs[1][2])
sns.histplot(data=df, x="mfcc_std", hue="sex", ax=axs[1][3])
sns.histplot(data=df, x="mfcc_min", hue="sex", ax=axs[2][1])
sns.histplot(data=df, x="mfcc_max", hue="sex", ax=axs[2][2])
sns.histplot(data=df, x="sc_mean", hue="sex", ax=axs[2][3])
sns.histplot(data=df, x="sc_min", hue="sex", ax=axs[3][1])
sns.histplot(data=df, x="sc_std", hue="sex", ax=axs[3][2])
sns.histplot(data=df, x="sc_max", hue="sex", ax=axs[3][3])
fig.show()

fig, axs=plt.subplots(4,4,figsize=(15,15))
sns.histplot(data=df, x="sc_skew", hue="sex", ax=axs[0][0])
sns.histplot(data=df, x="sc_kur", hue="sex", ax=axs[1][0])
sns.histplot(data=df, x="stft_mean", hue="sex", ax=axs[2][0])
sns.histplot(data=df, x="stft_std", hue="sex", ax=axs[3][0])
sns.histplot(data=df, x="stft_min", hue="sex", ax=axs[0][1])
sns.histplot(data=df, x="stft_kur", hue="sex", ax=axs[0][2])
sns.histplot(data=df, x="stft_skew", hue="sex", ax=axs[0][3])
sns.histplot(data=df, x="mean", hue="sex", ax=axs[1][1])
sns.histplot(data=df, x="std", hue="sex", ax=axs[1][2])
sns.histplot(data=df, x="min", hue="sex", ax=axs[1][3])
sns.histplot(data=df, x="max", hue="sex", ax=axs[2][1])
sns.histplot(data=df, x="skew", hue="sex", ax=axs[2][2])
sns.histplot(data=df, x="kur", hue="sex", ax=axs[2][3])
#sns.histplot(data=df, x="", hue="sex", ax=axs[3][1])
#sns.histplot(data=df, x="", hue="sex", ax=axs[3][2])
#sns.histplot(data=df, x="", hue="sex", ax=axs[3][3])
fig.show()
# Out:
# /tmp/ipykernel_5181/3170514600.py:19: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /tmp/ipykernel_5181/3170514600.py:38: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#istogrammi divisi per vocal channel
fig, axs=plt.subplots(4,4,figsize=(15,15))
sns.histplot(data=df, x="emotion", hue="vocal_channel", ax=axs[0][0])
sns.histplot(data=df, x="emotional_intensity", hue="vocal_channel", ax=axs[1][0])
sns.histplot(data=df, x="statement", hue="vocal_channel", ax=axs[2][0])
sns.histplot(data=df, x="repetition", hue="vocal_channel", ax=axs[3][0])
sns.histplot(data=df, x="length_ms", hue="vocal_channel", ax=axs[0][1])
sns.histplot(data=df, x="frame_count", hue="vocal_channel", ax=axs[0][2])
sns.histplot(data=df, x="intensity", hue="vocal_channel", ax=axs[0][3])
sns.histplot(data=df, x="zero_crossings_sum", hue="vocal_channel", ax=axs[1][1])
sns.histplot(data=df, x="mfcc_mean", hue="vocal_channel", ax=axs[1][2])
sns.histplot(data=df, x="mfcc_std", hue="vocal_channel", ax=axs[1][3])
sns.histplot(data=df, x="mfcc_min", hue="vocal_channel", ax=axs[2][1])
sns.histplot(data=df, x="mfcc_max", hue="vocal_channel", ax=axs[2][2])
sns.histplot(data=df, x="sc_mean", hue="vocal_channel", ax=axs[2][3])
sns.histplot(data=df, x="sc_min", hue="vocal_channel", ax=axs[3][1])
sns.histplot(data=df, x="sc_std", hue="vocal_channel", ax=axs[3][2])
sns.histplot(data=df, x="sc_max", hue="vocal_channel", ax=axs[3][3])
fig.show()

fig, axs=plt.subplots(4,4,figsize=(15,15))
sns.histplot(data=df, x="sc_skew", hue="vocal_channel", ax=axs[0][0])
sns.histplot(data=df, x="sc_kur", hue="vocal_channel", ax=axs[1][0])
sns.histplot(data=df, x="stft_mean", hue="vocal_channel", ax=axs[2][0])
sns.histplot(data=df, x="stft_std", hue="vocal_channel", ax=axs[3][0])
sns.histplot(data=df, x="stft_min", hue="vocal_channel", ax=axs[0][1])
sns.histplot(data=df, x="stft_kur", hue="vocal_channel", ax=axs[0][2])
sns.histplot(data=df, x="stft_skew", hue="vocal_channel", ax=axs[0][3])
#sns.histplot(data=df, x="mean", hue="sex", ax=axs[1][1])
sns.histplot(data=df, x="std", hue="vocal_channel", ax=axs[1][2])
sns.histplot(data=df, x="min", hue="vocal_channel", ax=axs[1][3])
sns.histplot(data=df, x="max", hue="vocal_channel", ax=axs[2][1])
sns.histplot(data=df, x="skew", hue="vocal_channel", ax=axs[2][2])
sns.histplot(data=df, x="kur", hue="vocal_channel", ax=axs[2][3])
#sns.histplot(data=df, x="", hue="sex", ax=axs[3][1])
#sns.histplot(data=df, x="", hue="sex", ax=axs[3][2])
#sns.histplot(data=df, x="", hue="sex", ax=axs[3][3])
fig.show()
# Out:
# /tmp/ipykernel_5181/324148993.py:19: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /tmp/ipykernel_5181/324148993.py:38: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
#boxplot divisi per emozione
fig, axs=plt.subplots(4,4,figsize=(15,15))
sns.boxplot(data=df, x="length_ms", y="emotion", ax=axs[0][0])
sns.boxplot(data=df, x="frame_count", y="emotion", ax=axs[0][1])
sns.boxplot(data=df, x="intensity", y="emotion", ax=axs[0][2])
sns.boxplot(data=df, x="zero_crossings_sum", y="emotion", ax=axs[0][3])
sns.boxplot(data=df, x="mfcc_mean", y="emotion", ax=axs[1][0])
sns.boxplot(data=df, x="mfcc_std", y="emotion", ax=axs[1][1])
sns.boxplot(data=df, x="mfcc_min", y="emotion", ax=axs[1][2])
sns.boxplot(data=df, x="mfcc_max", y="emotion", ax=axs[1][3])
sns.boxplot(data=df, x="sc_mean", y="emotion", ax=axs[2][0])
sns.boxplot(data=df, x="sc_std", y="emotion", ax=axs[2][1])
sns.boxplot(data=df, x="sc_max", y="emotion", ax=axs[2][2])
sns.boxplot(data=df, x="sc_min", y="emotion", ax=axs[2][3])
sns.boxplot(data=df, x="sc_kur", y="emotion", ax=axs[3][0])
sns.boxplot(data=df, x="sc_skew", y="emotion", ax=axs[3][1])
sns.boxplot(data=df, x="stft_mean", y="emotion", ax=axs[3][2])
sns.boxplot(data=df, x="stft_std", y="emotion", ax=axs[3][3])
fig.show()

fig, axs=plt.subplots(4,4,figsize=(15,15))
sns.boxplot(data=df, x="stft_min", y="emotion", ax=axs[0][0])
sns.boxplot(data=df, x="max", y="emotion", ax=axs[0][1])
sns.boxplot(data=df, x="stft_kur", y="emotion", ax=axs[0][2])
sns.boxplot(data=df, x="stft_skew", y="emotion", ax=axs[1][0])
#sns.boxplot(data=df, x="mean", y="emotion", ax=axs[1][1])
sns.boxplot(data=df, x="std", y="emotion", ax=axs[1][2])
sns.boxplot(data=df, x="min", y="emotion", ax=axs[2][0])
sns.boxplot(data=df, x="kur", y="emotion", ax=axs[2][1])
sns.boxplot(data=df, x="skew", y="emotion", ax=axs[2][2])
fig.show()

# %%
#boxplot divisi per genere
fig, axs=plt.subplots(4,4,figsize=(15,15))
sns.boxplot(data=df, x="length_ms", y="sex", ax=axs[0][0])
sns.boxplot(data=df, x="frame_count", y="sex", ax=axs[0][1])
sns.boxplot(data=df, x="intensity", y="sex", ax=axs[0][2])
sns.boxplot(data=df, x="zero_crossings_sum", y="sex", ax=axs[0][3])
sns.boxplot(data=df, x="mfcc_mean", y="sex", ax=axs[1][0])
sns.boxplot(data=df, x="mfcc_std", y="sex", ax=axs[1][1])
sns.boxplot(data=df, x="mfcc_min", y="sex", ax=axs[1][2])
sns.boxplot(data=df, x="mfcc_max", y="sex", ax=axs[1][3])
sns.boxplot(data=df, x="sc_mean", y="sex", ax=axs[2][0])
sns.boxplot(data=df, x="sc_std", y="sex", ax=axs[2][1])
sns.boxplot(data=df, x="sc_max", y="sex", ax=axs[2][2])
sns.boxplot(data=df, x="sc_min", y="sex", ax=axs[2][3])
sns.boxplot(data=df, x="sc_kur", y="sex", ax=axs[3][0])
sns.boxplot(data=df, x="sc_skew", y="sex", ax=axs[3][1])
sns.boxplot(data=df, x="stft_mean", y="sex", ax=axs[3][2])
sns.boxplot(data=df, x="stft_std", y="sex", ax=axs[3][3])
fig.show()

fig, axs=plt.subplots(3,3,figsize=(15,15))
sns.boxplot(data=df, x="stft_min", y="sex", ax=axs[0][0])
sns.boxplot(data=df, x="max", y="sex", ax=axs[0][1])
sns.boxplot(data=df, x="stft_kur", y="sex", ax=axs[0][2])
sns.boxplot(data=df, x="stft_skew", y="sex", ax=axs[1][0])
sns.boxplot(data=df, x="mean", y="sex", ax=axs[1][1])
sns.boxplot(data=df, x="std", y="sex", ax=axs[1][2])
sns.boxplot(data=df, x="min", y="sex", ax=axs[2][0])
sns.boxplot(data=df, x="kur", y="sex", ax=axs[2][1])
sns.boxplot(data=df, x="skew", y="sex", ax=axs[2][2])
fig.show()

# %% [markdown]
# ### Normality test

# %%
df
# Out:
#         modality vocal_channel  emotion  emotional_intensity  statement  \
# 0     audio-only        speech        0                    0          0
# 1     audio-only        speech        1                    0          0
# 2     audio-only           NaN        2                    1          0
# 3     audio-only           NaN        3                    0          1
# 4     audio-only          song        2                    1          0
# ...          ...           ...      ...                  ...        ...
# 2447  audio-only        speech        5                    1          1
# 2448  audio-only        speech        5                    0          0
# 2449  audio-only          song        6                    1          0
# 2450  audio-only        speech        3                    0          1
# 2451  audio-only           NaN        4                    0          0
#
#       repetition  actor  sex  channels  sample_width  ...  stft_max  stft_kur  \
# 0              1    2.0    1         1             2  ...       1.0 -1.215025
# 1              0   16.0    1         1             2  ...       1.0 -1.384174
# 2              1   16.0    1         1             2  ...       1.0 -1.242947
# 3              0   14.0    1         1             2  ...       1.0 -1.445318
# 4              1    2.0    1         1             2  ...       1.0 -1.366742
# ...          ...    ...  ...       ...           ...  ...       ...       ...
# 2447           0   23.0    0         1             2  ...       1.0 -1.075888
# 2448           0   23.0    0         1             2  ...       1.0 -1.026071
# 2449           1   23.0    0         1             2  ...       1.0 -1.473789
# 2450           0    NaN    0         1             2  ...       1.0 -1.277117
# 2451           1   23.0    0         1             2  ...       1.0 -1.257666
#
#       stft_skew          mean       std       min       max        kur  \
# 0      0.403514  3.844916e-07  0.014482 -0.128632  0.138947   9.406061
# 1      0.290905 -7.149491e-08  0.020417 -0.305725  0.263062  19.564187
# 2      0.470350  2.429985e-06  0.024317 -0.137482  0.166351   4.881241
# 3      0.274756  2.373929e-07  0.003561 -0.027374  0.024078  13.040259
# 4      0.318926  8.454691e-07  0.027522 -0.192169  0.242676   7.485109
# ...         ...           ...       ...       ...       ...        ...
# 2447  -0.310088  9.367040e-07  0.005260 -0.039856  0.052399   9.551363
# 2448  -0.408018  4.614221e-07  0.006836 -0.064178  0.084045  22.517991
# 2449   0.130310 -8.219263e-06  0.015384 -0.093079  0.097260   4.964319
# 2450  -0.242668 -4.400898e-06  0.005182 -0.057556  0.052002  13.855588
# 2451  -0.237757  6.342640e-07  0.010001 -0.081512  0.103027  12.973181
#
#           skew  vocal_channel_fill1
# 0     0.273153               speech
# 1     0.292157               speech
# 2     0.302659               speech
# 3    -0.081014               speech
# 4     0.414872                 song
# ...        ...                  ...
# 2447  0.759247               speech
# 2448  1.073633               speech
# 2449 -0.005821                 song
# 2450 -0.110966               speech
# 2451  1.032081               speech
#
# [2452 rows x 39 columns]

# %%
df["emotion"]=df["emotion"].replace(["fearful", "angry", "happy", "surprised", "neutral", "calm", "sad", "disgust"],[0,1,2,3,4,5,6,7])
df["emotional_intensity"]=df["emotional_intensity"].replace(["normal", "strong"],[0,1])
df["vocal_channel"]=df["vocal_channel"].replace(["speech", "song"],[0,1])
df["repetition"]=df["repetition"].replace(["1st", "2nd"],[0,1])
df["sex"]=df["sex"].replace(["M", "F"],[0,1])
df["statement"]=df["statement"].replace(["Dogs are sitting by the door", "Kids are talking by the door"],[0,1])
for i in df.drop(columns=["modality"]):
    stat, p = shapiro(df[i])
    if (p>0.05):
        print(i, stat, p, "  Shapiro: probably gaussian")
    else:
        print(i, stat, p, "  Shapiro: probably not gaussian")
# Out:
# vocal_channel nan 1.0   Shapiro: probably gaussian
# emotion 0.906316876411438 2.120309056000314e-36   Shapiro: probably not gaussian
# emotional_intensity 0.6344887614250183 0.0   Shapiro: probably not gaussian
# statement 0.6366180777549744 0.0   Shapiro: probably not gaussian
# repetition 0.6366180777549744 0.0   Shapiro: probably not gaussian
# actor nan 1.0   Shapiro: probably gaussian
# sex 0.6364985704421997 0.0   Shapiro: probably not gaussian
# channels 0.023883342742919922 0.0   Shapiro: probably not gaussian
# sample_width 1.0 1.0   Shapiro: probably gaussian
# frame_rate 1.0 1.0   Shapiro: probably gaussian
# frame_width 0.023883342742919922 0.0   Shapiro: probably not gaussian
# length_ms 0.9638106822967529 2.5573002919072092e-24   Shapiro: probably not gaussian
# frame_count 0.8501862287521362 2.620428128287408e-43   Shapiro: probably not gaussian
# intensity nan 1.0   Shapiro: probably gaussian
# zero_crossings_sum 0.9704989194869995 4.670527603532115e-22   Shapiro: probably not gaussian
# mfcc_mean 0.998197078704834 0.007722990121692419   Shapiro: probably not gaussian
# mfcc_std 0.9964406490325928 1.5591465853503905e-05   Shapiro: probably not gaussian
# mfcc_min 0.9985097646713257 0.026575790718197823   Shapiro: probably not gaussian
# mfcc_max 0.9919113516807556 1.8265471080081142e-10   Shapiro: probably not gaussian
# sc_mean 0.9963230490684509 1.0786129678308498e-05   Shapiro: probably not gaussian
# sc_std 0.9820463061332703 4.732001837650862e-17   Shapiro: probably not gaussian
# sc_min 0.8305356502532959 2.802596928649634e-45   Shapiro: probably not gaussian
# sc_max 0.84940505027771 2.1860256043467146e-43   Shapiro: probably not gaussian
# sc_kur 0.7494524717330933 0.0   Shapiro: probably not gaussian
# sc_skew 0.9881080985069275 1.9974196992580961e-13   Shapiro: probably not gaussian
# stft_mean 0.9945856928825378 8.049320854297548e-08   Shapiro: probably not gaussian
# stft_std 0.9706883430480957 5.479423303826334e-22   Shapiro: probably not gaussian
# stft_min 0.5300661325454712 0.0   Shapiro: probably not gaussian
# stft_max 1.0 1.0   Shapiro: probably gaussian
# stft_kur 0.8750886917114258 1.4707187902474685e-40   Shapiro: probably not gaussian
# stft_skew 0.9956511855125427 1.4485743804470985e-06   Shapiro: probably not gaussian
# mean 0.19872653484344482 0.0   Shapiro: probably not gaussian
# std 0.7551526427268982 0.0   Shapiro: probably not gaussian
# min 0.7375707626342773 0.0   Shapiro: probably not gaussian
# max 0.735848069190979 0.0   Shapiro: probably not gaussian
# kur 0.8504968285560608 2.8166099132928823e-43   Shapiro: probably not gaussian
# skew 0.9855433702468872 4.376328282645588e-15   Shapiro: probably not gaussian
# /home/alessandro/anaconda3/lib/python3.9/site-packages/scipy/stats/morestats.py:1757: UserWarning: Input data for shapiro has range zero. The results may not be accurate.
#   warnings.warn("Input data for shapiro has range zero. The results "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 7>()
#       6 df["statement"]=df["statement"].replace(["Dogs are sitting by the door", "Kids are talking by the door"],[0,1])
#       7 for i in df.drop(columns=["modality"]):
# ----> 8     stat, p = shapiro(df[i])
#       9     if (p>0.05):
#      10         print(i, stat, p, "  Shapiro: probably gaussian")
#
# File ~/anaconda3/lib/python3.9/site-packages/scipy/stats/morestats.py:1755, in shapiro(x)
#    1752 init = 0
#    1754 y = sort(x)
# -> 1755 a, w, pw, ifault = statlib.swilk(y, a[:N//2], init)
#    1756 if ifault not in [0, 2]:
#    1757     warnings.warn("Input data for shapiro has range zero. The results "
#    1758                   "may not be accurate.")
#
# ValueError: could not convert string to float: 'song'

# %% [markdown]
# ### Missing values vocal_channel

# %%
#dfnull=df[df["emotion"]=="happy"]
len(df[df["vocal_channel"].isnull()])

# %%
fig, axs=plt.subplots(5,2,figsize=(40,30))
sns.histplot(data=df, x="length_ms", hue="vocal_channel", ax=axs[0][0], bins=100)
sns.histplot(data=df, x="intensity", hue="vocal_channel", ax=axs[0][1], bins=100)
sns.histplot(data=df, x="frame_count", hue="vocal_channel", ax=axs[1][0], bins=100)
sns.histplot(data=df, x="mfcc_std", hue="vocal_channel", ax=axs[1][1], bins=100)
sns.histplot(data=df, x="sc_mean", hue="vocal_channel", ax=axs[2][0], bins=100)
sns.histplot(data=df, x="sc_skew", hue="vocal_channel", ax=axs[2][1], bins=100)
sns.histplot(data=df, x="stft_skew", hue="vocal_channel", ax=axs[3][0], bins=100)
sns.histplot(data=df, x="stft_mean", hue="vocal_channel", ax=axs[3][1], bins=100)
sns.histplot(data=df, x="stft_std", hue="vocal_channel", ax=axs[4][0], bins=100)
sns.histplot(data=df, x="kur", hue="vocal_channel", ax=axs[4][1], bins=100)
fig.show()

# %%
dfcopy2=df.copy()
dfcopy1=df

# %%
#rimpiazzo dei Nan in vocal channel (metodo sbagliato)
df["vocal_channel_fill2"] = np.where(
    (df["vocal_channel"].isnull()) & (df["frame_count"]>1) &
    ((df["frame_count"]<190000) | (df["length_ms"]<4000) | (df["intensity"]<-45) | (df["mfcc_std"]>155) | (df["sc_mean"]>5500) | (df["sc_skew"]<0.25) | (df["sc_mean"]>5700) | (df["stft_skew"]<-0.1) | (df["stft_mean"]>0.52) | (df["stft_std"]<0.315) | (df["kur"]>13)), "speech", df["vocal_channel"])
df["vocal_channel_fill2"] = np.where(
    (df["vocal_channel"].isnull()) &
    ((df["frame_count"]>210000) | (df["length_ms"]>4250) | (df["sc_mean"]<4000) | (df["stft_skew"]>0.48) | (df["stft_mean"]<0.35) | (df["kur"]<6)), "song", df["vocal_channel"])

# %%
len(df[df["vocal_channel"].isnull()])

# %%
df["vocal_channel_fill2"].count()

# %%
df

# %%
dfspeech=df[df["vocal_channel"]==1.0]
dfsong=df[df["vocal_channel"]==0.0]
dfspeech

# %%
fig, axs=plt.subplots(2,2,figsize=(15,15))
sns.histplot(data=dfcopy1, x="length_ms", hue="vocal_channel", ax=axs[0][0])
sns.histplot(data=dfcopy1, x="frame_count", hue="vocal_channel", ax=axs[1][0])
sns.histplot(data=df, x="length_ms", hue="vocal_channel", ax=axs[0][1])
sns.histplot(data=df, x="frame_count", hue="vocal_channel", ax=axs[1][1])
fig.show()

# %% [markdown]
# # Emozioni

# %% [markdown]
# Analisi separata per intensità dell'emozione

# %%
df.head()

# %%
dfnormal=df[df["emotional_intensity"]==1]
dfstrong=df[df["emotional_intensity"]==0]

# %%
#min dfstrong
fig, axs = plt.subplots(2,2,figsize=(15,15))
sns.kdeplot(data=dfstrong, x="min", hue="emotion", ax=axs[0][0])
sns.kdeplot(data=dfstrong, x="mfcc_min", hue="emotion", ax=axs[0][1])
sns.kdeplot(data=dfstrong, x="sc_min", hue="emotion", ax=axs[1][0])
sns.kdeplot(data=dfstrong, x="stft_min", hue="emotion", ax=axs[1][1])

# %%
#min dfnormal
fig, axs = plt.subplots(2,2,figsize=(15,15))
sns.kdeplot(data=dfnormal, x="min", hue="emotion", ax=axs[0][0])
sns.kdeplot(data=dfnormal, x="mfcc_min", hue="emotion", ax=axs[0][1])
sns.kdeplot(data=dfnormal, x="sc_min", hue="emotion", ax=axs[1][0])
sns.kdeplot(data=dfnormal, x="stft_min", hue="emotion", ax=axs[1][1])

# %%
#mean dfnormal
fig, axs = plt.subplots(2,2,figsize=(15,15))
sns.kdeplot(data=dfnormal, x="mean", hue="emotion", ax=axs[0][0])
sns.kdeplot(data=dfnormal, x="mfcc_mean", hue="emotion", ax=axs[0][1])
sns.kdeplot(data=dfnormal, x="sc_mean", hue="emotion", ax=axs[1][0])
sns.kdeplot(data=dfnormal, x="stft_mean", hue="emotion", ax=axs[1][1])

# %%
#mean dfstrong
fig, axs = plt.subplots(2,2,figsize=(15,15))
sns.kdeplot(data=dfstrong, x="mean", hue="emotion", ax=axs[0][0])
sns.kdeplot(data=dfstrong, x="mfcc_mean", hue="emotion", ax=axs[0][1])
sns.kdeplot(data=dfstrong, x="sc_mean", hue="emotion", ax=axs[1][0])
sns.kdeplot(data=dfstrong, x="stft_mean", hue="emotion", ax=axs[1][1])

# %%
#std dfnormal
fig, axs = plt.subplots(2,2,figsize=(15,15))
sns.kdeplot(data=dfnormal, x="std", hue="emotion", ax=axs[0][0])
sns.kdeplot(data=dfnormal, x="mfcc_std", hue="emotion", ax=axs[0][1])
sns.kdeplot(data=dfnormal, x="sc_std", hue="emotion", ax=axs[1][0])
sns.kdeplot(data=dfnormal, x="stft_std", hue="emotion", ax=axs[1][1])

# %%
#std dfstrong
fig, axs = plt.subplots(2,2,figsize=(15,15))
sns.kdeplot(data=dfstrong, x="std", hue="emotion", ax=axs[0][0])
sns.kdeplot(data=dfstrong, x="mfcc_std", hue="emotion", ax=axs[0][1])
sns.kdeplot(data=dfstrong, x="sc_std", hue="emotion", ax=axs[1][0])
sns.kdeplot(data=dfstrong, x="stft_std", hue="emotion", ax=axs[1][1])

# %%
#skew and length dfnormal
fig, axs = plt.subplots(2,2,figsize=(15,15))
sns.kdeplot(data=dfnormal, x="skew", hue="emotion", ax=axs[0][0])
sns.kdeplot(data=dfnormal, x="length_ms", hue="emotion", ax=axs[0][1])
sns.kdeplot(data=dfnormal, x="sc_skew", hue="emotion", ax=axs[1][0])
sns.kdeplot(data=dfnormal, x="stft_skew", hue="emotion", ax=axs[1][1])

# %%
#skew and length dfstrong
fig, axs = plt.subplots(2,2,figsize=(15,15))
sns.kdeplot(data=dfstrong, x="skew", hue="emotion", ax=axs[0][0])
sns.kdeplot(data=dfstrong, x="length_ms", hue="emotion", ax=axs[0][1])
sns.kdeplot(data=dfstrong, x="sc_skew", hue="emotion", ax=axs[1][0])
sns.kdeplot(data=dfstrong, x="stft_skew", hue="emotion", ax=axs[1][1])

# %%
#zero-crossing-sum and kurtosis dfnormal
fig, axs = plt.subplots(2,2,figsize=(15,15))
sns.kdeplot(data=dfnormal, x="kur", hue="emotion", ax=axs[0][0])
sns.kdeplot(data=dfnormal, x="zero_crossings_sum", hue="emotion", ax=axs[0][1])
sns.kdeplot(data=dfnormal, x="sc_kur", hue="emotion", ax=axs[1][0])
sns.kdeplot(data=dfnormal, x="stft_kur", hue="emotion", ax=axs[1][1])

# %%
#zero-crossing-sum and kurtosis dfstrong
fig, axs = plt.subplots(2,2,figsize=(15,15))
sns.kdeplot(data=dfstrong, x="kur", hue="emotion", ax=axs[0][0])
sns.kdeplot(data=dfstrong, x="zero_crossings_sum", hue="emotion", ax=axs[0][1])
sns.kdeplot(data=dfstrong, x="sc_kur", hue="emotion", ax=axs[1][0])
sns.kdeplot(data=dfstrong, x="stft_kur", hue="emotion", ax=axs[1][1])

# %%
sns.kdeplot(data=dfstrong, x="frame_count", hue="emotion")

# %% [markdown]
# ### Analisi bivariabile (boh)

# %%
sns.scatterplot(data=dfstrong, x="std", y="intensity", hue="emotion")

# %%
sns.scatterplot(data=dfstrong, x="kur", y="stft_mean", hue="emotion")

# %%
sns.boxplot(data=df, x="mfcc_mean", y="emotion")

# %%
sns.boxplot(data=df, x="mfcc_std", y="emotion")

# %%
sns.boxplot(data=df, x="mfcc_min", y="emotion")

# %%
sns.boxplot(data=df, x="mfcc_max", y="emotion")

# %%
sns.boxplot(data=df, x="std", y="emotion")

# %%
sns.boxplot(data=df, x="min", y="emotion")

# %%
sns.boxplot(data=df, x="max", y="emotion")

# %%
sns.boxplot(data=df, x="length_ms", y="emotion")

# %%
sns.boxplot(data=df, x="intensity", y="emotion")

# %%
sns.boxplot(data=df, x="frame_count", y="emotion")

# %%
df.corr().loc[["intensity_fill", "sex", "emotion", "emotional_intensity", "mfcc_std", "mfcc_min", "sc_mean", "sc_std", "sc_kur", "sc_skew", "stft_mean", "stft_std", "stft_skew", "std", "min", "max"], ["intensity", "sex", "emotion", "emotional_intensity", "mfcc_std", "mfcc_min", "sc_mean", "sc_std", "sc_kur", "sc_skew", "stft_mean", "stft_std", "stft_skew", "std", "min", "max"]].style.background_gradient(cmap="coolwarm", vmin=-1, vmax=1)
